# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import KFold,cross_validate,GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier

# %%
df=pd.read_csv('Churn.csv')

# %%
df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    LA             117        408                 No              No
# 1    IN              65        415                 No              No
# 2    NY             161        415                 No              No
# 3    SC             111        415                 No              No
# 4    HI              49        510                 No              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                      0              184.5               97
# 1                      0              129.1              137
# 2                      0              332.9               67
# 3                      0              110.4              103
# 4                      0              119.3              117
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             31.37              351.6               80             29.89
# 1             21.95              228.5               83             19.42
# 2             56.59              317.8               97             27.01
# 3             18.77              137.3              102             11.67
# 4             20.28              215.1              109             18.28
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                215.8                 90                9.71
# 1                208.8                111                9.40
# 2                160.6                128                7.23
# 3                189.6                105                8.53
# 4                178.7                 90                8.04
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                 8.7                 4               2.35
# 1                12.7                 6               3.43
# 2                 5.4                 9               1.46
# 3                 7.7                 6               2.08
# 4                11.1                 1               3.00
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       4   True
# 2                       4   True
# 3                       2  False
# 4                       1  False

# %%
df.drop('State',axis=1,inplace=True)
df['International plan']=df['International plan'].map({'No':0,'Yes':1})
df['Voice mail plan']=df['Voice mail plan'].map({'No':0,'Yes':1})
df['Churn']=df['Churn'].astype(int)

# %%
df.drop({'Area code'},axis=1,inplace=True)

# %%
df.head()
# Out:
#    Account length  International plan  Voice mail plan  Number vmail messages  \
# 0             117                   0                0                      0
# 1              65                   0                0                      0
# 2             161                   0                0                      0
# 3             111                   0                0                      0
# 4              49                   0                0                      0
#
#    Total day minutes  Total day calls  Total day charge  Total eve minutes  \
# 0              184.5               97             31.37              351.6
# 1              129.1              137             21.95              228.5
# 2              332.9               67             56.59              317.8
# 3              110.4              103             18.77              137.3
# 4              119.3              117             20.28              215.1
#
#    Total eve calls  Total eve charge  Total night minutes  Total night calls  \
# 0               80             29.89                215.8                 90
# 1               83             19.42                208.8                111
# 2               97             27.01                160.6                128
# 3              102             11.67                189.6                105
# 4              109             18.28                178.7                 90
#
#    Total night charge  Total intl minutes  Total intl calls  \
# 0                9.71                 8.7                 4
# 1                9.40                12.7                 6
# 2                7.23                 5.4                 9
# 3                8.53                 7.7                 6
# 4                8.04                11.1                 1
#
#    Total intl charge  Customer service calls  Churn
# 0               2.35                       1      0
# 1               3.43                       4      1
# 2               1.46                       4      1
# 3               2.08                       2      0
# 4               3.00                       1      0

# %%
target=df['Churn']
X=df.drop(['Churn'],axis=1)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,target,test_size=0.2,random_state=123)

# %% [markdown]
# # DECISION_TREE

# %%
tree_model=DecisionTreeClassifier(random_state=1)
fold=KFold(n_splits=5)

par_tree={
    'max_depth' : [8,10,12],
    'min_samples_leaf' : [5,10]
}

# %%
grid_tree=GridSearchCV(tree_model,param_grid=par_tree,cv=5,verbose=1)

# %%
grid_tree.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(random_state=1),
#              param_grid={'max_depth': [8, 10, 12], 'min_samples_leaf': [5, 10]},
#              verbose=1)

# %%
grid_tree.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=8, min_samples_leaf=5, random_state=1)

# %%
grid_tree.cv_results_
# Out:
# {'mean_fit_time': array([0.01449914, 0.01369839, 0.0160985 , 0.0157968 , 0.01829872,
#         0.01789808]),
#  'std_fit_time': array([0.00044822, 0.00039981, 0.00020254, 0.00040026, 0.00040319,
#         0.00066003]),
#  'mean_score_time': array([0.00100284, 0.00120354, 0.00160384, 0.0014039 , 0.00140538,
#         0.00100522]),
#  'std_score_time': array([1.60574515e-06, 3.99948144e-04, 4.90076752e-04, 4.90096112e-04,
#         4.89382777e-04, 7.44843452e-07]),
#  'param_max_depth': masked_array(data=[8, 8, 10, 10, 12, 12],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'param_min_samples_leaf': masked_array(data=[5, 10, 5, 10, 5, 10],
#               mask=[False, False, False, False, False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'max_depth': 8, 'min_samples_leaf': 5},
#   {'max_depth': 8, 'min_samples_leaf': 10},
#   {'max_depth': 10, 'min_samples_leaf': 5},
#   {'max_depth': 10, 'min_samples_leaf': 10},
#   {'max_depth': 12, 'min_samples_leaf': 5},
#   {'max_depth': 12, 'min_samples_leaf': 10}],
#  'split0_test_score': array([0.93258427, 0.93445693, 0.92883895, 0.93445693, 0.92883895,
#         0.93445693]),
#  'split1_test_score': array([0.94934334, 0.94934334, 0.94746717, 0.94934334, 0.94746717,
#         0.94934334]),
#  'split2_test_score': array([0.93621013, 0.93433396, 0.9380863 , 0.93433396, 0.9380863 ,
#         0.93433396]),
#  'split3_test_score': array([0.94183865, 0.93245779, 0.93621013, 0.93245779, 0.9380863 ,
#         0.93245779]),
#  'split4_test_score': array([0.93245779, 0.92870544, 0.93058161, 0.92870544, 0.93245779,
#         0.92870544]),
#  'mean_test_score': array([0.93848684, 0.93585949, 0.93623683, 0.93585949, 0.9369873 ,
#         0.93585949]),
#  'std_test_score': array([0.00641048, 0.00705494, 0.0065765 , 0.00705494, 0.00631119,
#         0.00705494]),
#  'rank_test_score': array([1, 4, 3, 4, 2, 4])}

# %%
pred_tree=grid_tree.predict(X_test)
print(classification_report(y_test,pred_tree))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.98      0.96       561
#            1       0.87      0.74      0.80       106
#
#     accuracy                           0.94       667
#    macro avg       0.91      0.86      0.88       667
# weighted avg       0.94      0.94      0.94       667

# %% [markdown]
# # Random_Forest

# %%
rf_model=RandomForestClassifier(random_state=1)

# %%
param_rf={
    'n_estimators':[25,50,75],
    'max_depth': [8,10,12],
    'max_features':[4,5,6,7]
}

# %%
grid_rf=GridSearchCV(rf_model,param_grid=param_rf,cv=5,verbose=1)

# %%
grid_rf.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# GridSearchCV(cv=5, estimator=RandomForestClassifier(random_state=1),
#              param_grid={'max_depth': [8, 10, 12], 'max_features': [4, 5, 6, 7],
#                          'n_estimators': [25, 50, 75]},
#              verbose=1)

# %%
grid_rf.best_estimator_
# Out:
# RandomForestClassifier(max_depth=12, max_features=7, n_estimators=25,
#                        random_state=1)

# %%
print(grid_rf.cv_results_['mean_test_score'].mean())
print(grid_rf.cv_results_['std_test_score'].mean())
# Out:
# 0.9584056905103766
# 0.004799215396002439

# %%
pred_rf=grid_rf.predict(X_test)
print(classification_report(y_test,pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       561
#            1       0.93      0.79      0.86       106
#
#     accuracy                           0.96       667
#    macro avg       0.95      0.89      0.92       667
# weighted avg       0.96      0.96      0.96       667

# %%
gbc_model=GradientBoostingClassifier(random_state=1)

# %%
par_gbc={
    'n_estimators':[50,100,150],
    'learning_rate':[0.1,0.05,0.01],
    'max_depth':[3,4,5]
}

# %%
grid_gbc=GridSearchCV(gbc_model,param_grid=par_gbc,cv=fold,verbose=1)

# %%
grid_gbc.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=GradientBoostingClassifier(random_state=1),
#              param_grid={'learning_rate': [0.1, 0.05, 0.01],
#                          'max_depth': [3, 4, 5],
#                          'n_estimators': [50, 100, 150]},
#              verbose=1)

# %%
grid_gbc.best_estimator_
# Out:
# GradientBoostingClassifier(max_depth=5, n_estimators=150, random_state=1)

# %%
print(grid_gbc.cv_results_['mean_test_score'].mean())
print(grid_gbc.cv_results_['std_test_score'].mean())
# Out:
# 0.93924831296714
# 0.007620048059806471

# %%
gbc=GradientBoostingClassifier(random_state=1,learning_rate=0.05,max_depth=5,n_estimators=150)

# %%
gbc.fit(X_train,y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.05, max_depth=5, n_estimators=150,
#                            random_state=1)

# %%
gbc_pred=gbc.predict(X_test)

# %%
print(classification_report(y_test,gbc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       561
#            1       0.94      0.82      0.87       106
#
#     accuracy                           0.96       667
#    macro avg       0.95      0.91      0.93       667
# weighted avg       0.96      0.96      0.96       667

# %%
import xgboost as xgb

# %%
xgc=xgb.XGBClassifier( objective='binary:logistic')

par_xgb={
   
    'n_estimators' : [50,75,100,120],
    'eta' : [0.1,0.05],
    'max_depth':[4,5]
}

# %%
grid_xgb=GridSearchCV(xgc,param_grid=par_xgb,cv=fold,verbose=1)

# %%
grid_xgb.fit(X_train,y_train, eval_set=[(X_train,y_train),(X_train,y_train)],
          eval_metric=['logloss','error'],
          verbose=True)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [0]	validation_0-logloss:0.39046	validation_0-error:0.14816	validation_1-logloss:0.39046	validation_1-error:0.14816
# [1]	validation_0-logloss:0.36221	validation_0-error:0.14816	validation_1-logloss:0.36221	validation_1-error:0.14816
# [2]	validation_0-logloss:0.33880	validation_0-error:0.14816	validation_1-logloss:0.33880	validation_1-error:0.14816
# [3]	validation_0-logloss:0.31911	validation_0-error:0.14816	validation_1-logloss:0.31911	validation_1-error:0.14816
# [4]	validation_0-logloss:0.30179	validation_0-error:0.12603	validation_1-logloss:0.30179	validation_1-error:0.12603
# [5]	validation_0-logloss:0.28639	validation_0-error:0.09865	validation_1-logloss:0.28639	validation_1-error:0.09865
# [6]	validation_0-logloss:0.27366	validation_0-error:0.09752	validation_1-logloss:0.27366	validation_1-error:0.09752
# [7]	validation_0-logloss:0.26248	validation_0-error:0.09377	validation_1-logloss:0.26248	validation_1-error:0.09377
# [8]	validation_0-logloss:0.25203	validation_0-error:0.08965	validation_1-logloss:0.25203	validation_1-error:0.08965
# [9]	validation_0-logloss:0.24322	validation_0-error:0.07989	validation_1-logloss:0.24322	validation_1-error:0.07989
# [10]	validation_0-logloss:0.23310	validation_0-error:0.06827	validation_1-logloss:0.23310	validation_1-error:0.06827
# [11]	validation_0-logloss:0.22444	validation_0-error:0.06602	validation_1-logloss:0.22444	validation_1-error:0.06602
# [12]	validation_0-logloss:0.21753	validation_0-error:0.06189	validation_1-logloss:0.21753	validation_1-error:0.06189
# [13]	validation_0-logloss:0.21060	validation_0-error:0.05139	validation_1-logloss:0.21060	validation_1-error:0.05139
# [14]	validation_0-logloss:0.20465	validation_0-error:0.05026	validation_1-logloss:0.20465	validation_1-error:0.05026
# [15]	validation_0-logloss:0.19934	validation_0-error:0.04876	validation_1-logloss:0.19934	validation_1-error:0.04876
# [16]	validation_0-logloss:0.19513	validation_0-error:0.04614	validation_1-logloss:0.19513	validation_1-error:0.04614
# [17]	validation_0-logloss:0.19036	validation_0-error:0.04426	validation_1-logloss:0.19036	validation_1-error:0.04426
# [18]	validation_0-logloss:0.18656	validation_0-error:0.03938	validation_1-logloss:0.18656	validation_1-error:0.03938
# [19]	validation_0-logloss:0.18316	validation_0-error:0.03938	validation_1-logloss:0.18316	validation_1-error:0.03938
# [20]	validation_0-logloss:0.18001	validation_0-error:0.03788	validation_1-logloss:0.18001	validation_1-error:0.03788
# [21]	validation_0-logloss:0.17722	validation_0-error:0.03788	validation_1-logloss:0.17722	validation_1-error:0.03788
# [22]	validation_0-logloss:0.17452	validation_0-error:0.03638	validation_1-logloss:0.17452	validation_1-error:0.03638
# [23]	validation_0-logloss:0.17119	validation_0-error:0.03526	validation_1-logloss:0.17119	validation_1-error:0.03526
# [24]	validation_0-logloss:0.16927	validation_0-error:0.03376	validation_1-logloss:0.16927	validation_1-error:0.03376
# [25]	validation_0-logloss:0.16593	validation_0-error:0.03413	validation_1-logloss:0.16593	validation_1-error:0.03413
# [26]	validation_0-logloss:0.16327	validation_0-error:0.03413	validation_1-logloss:0.16327	validation_1-error:0.03413
# [27]	validation_0-logloss:0.16060	validation_0-error:0.03338	validation_1-logloss:0.16060	validation_1-error:0.03338
# [28]	validation_0-logloss:0.15852	validation_0-error:0.03338	validation_1-logloss:0.15852	validation_1-error:0.03338
# [29]	validation_0-logloss:0.15636	validation_0-error:0.03338	validation_1-logloss:0.15636	validation_1-error:0.03338
# [30]	validation_0-logloss:0.15432	validation_0-error:0.03226	validation_1-logloss:0.15432	validation_1-error:0.03226
# [31]	validation_0-logloss:0.15294	validation_0-error:0.03301	validation_1-logloss:0.15294	validation_1-error:0.03301
# [32]	validation_0-logloss:0.15146	validation_0-error:0.03263	validation_1-logloss:0.15146	validation_1-error:0.03263
# [33]	validation_0-logloss:0.15017	validation_0-error:0.03226	validation_1-logloss:0.15017	validation_1-error:0.03226
# [34]	validation_0-logloss:0.14806	validation_0-error:0.03188	validation_1-logloss:0.14806	validation_1-error:0.03188
# [35]	validation_0-logloss:0.14661	validation_0-error:0.03263	validation_1-logloss:0.14661	validation_1-error:0.03263
# [36]	validation_0-logloss:0.14573	validation_0-error:0.03263	validation_1-logloss:0.14573	validation_1-error:0.03263
# [37]	validation_0-logloss:0.14396	validation_0-error:0.03188	validation_1-logloss:0.14396	validation_1-error:0.03188
# [38]	validation_0-logloss:0.14310	validation_0-error:0.03113	validation_1-logloss:0.14310	validation_1-error:0.03113
# [39]	validation_0-logloss:0.14171	validation_0-error:0.03038	validation_1-logloss:0.14171	validation_1-error:0.03038
# [40]	validation_0-logloss:0.14010	validation_0-error:0.03113	validation_1-logloss:0.14010	validation_1-error:0.03113
# [41]	validation_0-logloss:0.13890	validation_0-error:0.03038	validation_1-logloss:0.13890	validation_1-error:0.03038
# [42]	validation_0-logloss:0.13791	validation_0-error:0.03076	validation_1-logloss:0.13791	validation_1-error:0.03076
# [43]	validation_0-logloss:0.13708	validation_0-error:0.03076	validation_1-logloss:0.13708	validation_1-error:0.03076
# [44]	validation_0-logloss:0.13614	validation_0-error:0.03001	validation_1-logloss:0.13614	validation_1-error:0.03001
# [45]	validation_0-logloss:0.13439	validation_0-error:0.03001	validation_1-logloss:0.13439	validation_1-error:0.03001
# [46]	validation_0-logloss:0.13309	validation_0-error:0.02963	validation_1-logloss:0.13309	validation_1-error:0.02963
# [47]	validation_0-logloss:0.13210	validation_0-error:0.02926	validation_1-logloss:0.13210	validation_1-error:0.02926
# [48]	validation_0-logloss:0.13142	validation_0-error:0.02926	validation_1-logloss:0.13142	validation_1-error:0.02926
# [49]	validation_0-logloss:0.13036	validation_0-error:0.02963	validation_1-logloss:0.13036	validation_1-error:0.02963
# [0]	validation_0-logloss:0.38944	validation_0-error:0.14816	validation_1-logloss:0.38944	validation_1-error:0.14816
# C:\Users\prash\anaconda3\Lib\site-packages\xgboost\sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\prash\anaconda3\Lib\site-packages\xgboost\sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [1]	validation_0-logloss:0.35907	validation_0-error:0.14816	validation_1-logloss:0.35907	validation_1-error:0.14816
# [2]	validation_0-logloss:0.33494	validation_0-error:0.14816	validation_1-logloss:0.33494	validation_1-error:0.14816
# [3]	validation_0-logloss:0.31552	validation_0-error:0.14666	validation_1-logloss:0.31552	validation_1-error:0.14666
# [4]	validation_0-logloss:0.29883	validation_0-error:0.11890	validation_1-logloss:0.29883	validation_1-error:0.11890
# [5]	validation_0-logloss:0.28419	validation_0-error:0.09940	validation_1-logloss:0.28419	validation_1-error:0.09940
# [6]	validation_0-logloss:0.27148	validation_0-error:0.09415	validation_1-logloss:0.27148	validation_1-error:0.09415
# [7]	validation_0-logloss:0.26056	validation_0-error:0.08815	validation_1-logloss:0.26056	validation_1-error:0.08815
# [8]	validation_0-logloss:0.24832	validation_0-error:0.08402	validation_1-logloss:0.24832	validation_1-error:0.08402
# [9]	validation_0-logloss:0.23788	validation_0-error:0.08252	validation_1-logloss:0.23788	validation_1-error:0.08252
# [10]	validation_0-logloss:0.22897	validation_0-error:0.06827	validation_1-logloss:0.22897	validation_1-error:0.06827
# [11]	validation_0-logloss:0.22124	validation_0-error:0.05551	validation_1-logloss:0.22124	validation_1-error:0.05551
# [12]	validation_0-logloss:0.21258	validation_0-error:0.05589	validation_1-logloss:0.21258	validation_1-error:0.05589
# [13]	validation_0-logloss:0.20531	validation_0-error:0.05326	validation_1-logloss:0.20531	validation_1-error:0.05326
# [14]	validation_0-logloss:0.19907	validation_0-error:0.04876	validation_1-logloss:0.19907	validation_1-error:0.04876
# [15]	validation_0-logloss:0.19378	validation_0-error:0.04201	validation_1-logloss:0.19378	validation_1-error:0.04201
# [16]	validation_0-logloss:0.18908	validation_0-error:0.04126	validation_1-logloss:0.18908	validation_1-error:0.04126
# [17]	validation_0-logloss:0.18543	validation_0-error:0.04276	validation_1-logloss:0.18543	validation_1-error:0.04276
# [18]	validation_0-logloss:0.18107	validation_0-error:0.04164	validation_1-logloss:0.18107	validation_1-error:0.04164
# [19]	validation_0-logloss:0.17822	validation_0-error:0.04089	validation_1-logloss:0.17822	validation_1-error:0.04089
# [20]	validation_0-logloss:0.17527	validation_0-error:0.04051	validation_1-logloss:0.17527	validation_1-error:0.04051
# [21]	validation_0-logloss:0.17202	validation_0-error:0.03901	validation_1-logloss:0.17202	validation_1-error:0.03901
# [22]	validation_0-logloss:0.17003	validation_0-error:0.03901	validation_1-logloss:0.17003	validation_1-error:0.03901
# [23]	validation_0-logloss:0.16781	validation_0-error:0.03901	validation_1-logloss:0.16781	validation_1-error:0.03901
# [24]	validation_0-logloss:0.16493	validation_0-error:0.03826	validation_1-logloss:0.16493	validation_1-error:0.03826
# [25]	validation_0-logloss:0.16243	validation_0-error:0.03826	validation_1-logloss:0.16243	validation_1-error:0.03826
# [26]	validation_0-logloss:0.16072	validation_0-error:0.03788	validation_1-logloss:0.16072	validation_1-error:0.03788
# [27]	validation_0-logloss:0.15897	validation_0-error:0.03788	validation_1-logloss:0.15897	validation_1-error:0.03788
# [28]	validation_0-logloss:0.15675	validation_0-error:0.03638	validation_1-logloss:0.15675	validation_1-error:0.03638
# [29]	validation_0-logloss:0.15551	validation_0-error:0.03526	validation_1-logloss:0.15551	validation_1-error:0.03526
# [30]	validation_0-logloss:0.15353	validation_0-error:0.03526	validation_1-logloss:0.15353	validation_1-error:0.03526
# [31]	validation_0-logloss:0.15249	validation_0-error:0.03376	validation_1-logloss:0.15249	validation_1-error:0.03376
# [32]	validation_0-logloss:0.15080	validation_0-error:0.03413	validation_1-logloss:0.15080	validation_1-error:0.03413
# [33]	validation_0-logloss:0.14832	validation_0-error:0.03301	validation_1-logloss:0.14832	validation_1-error:0.03301
# [34]	validation_0-logloss:0.14735	validation_0-error:0.03338	validation_1-logloss:0.14735	validation_1-error:0.03338
# [35]	validation_0-logloss:0.14596	validation_0-error:0.03301	validation_1-logloss:0.14596	validation_1-error:0.03301
# [36]	validation_0-logloss:0.14503	validation_0-error:0.03188	validation_1-logloss:0.14503	validation_1-error:0.03188
# [37]	validation_0-logloss:0.14390	validation_0-error:0.03113	validation_1-logloss:0.14390	validation_1-error:0.03113
# [38]	validation_0-logloss:0.14257	validation_0-error:0.03113	validation_1-logloss:0.14257	validation_1-error:0.03113
# [39]	validation_0-logloss:0.14154	validation_0-error:0.03113	validation_1-logloss:0.14154	validation_1-error:0.03113
# [40]	validation_0-logloss:0.14008	validation_0-error:0.03113	validation_1-logloss:0.14008	validation_1-error:0.03113
# [41]	validation_0-logloss:0.13889	validation_0-error:0.03113	validation_1-logloss:0.13889	validation_1-error:0.03113
# [42]	validation_0-logloss:0.13795	validation_0-error:0.03076	validation_1-logloss:0.13795	validation_1-error:0.03076
# [43]	validation_0-logloss:0.13687	validation_0-error:0.03076	validation_1-logloss:0.13687	validation_1-error:0.03076
# [44]	validation_0-logloss:0.13578	validation_0-error:0.03076	validation_1-logloss:0.13578	validation_1-error:0.03076
# [45]	validation_0-logloss:0.13498	validation_0-error:0.03038	validation_1-logloss:0.13498	validation_1-error:0.03038
# [46]	validation_0-logloss:0.13405	validation_0-error:0.03076	validation_1-logloss:0.13405	validation_1-error:0.03076
# [47]	validation_0-logloss:0.13309	validation_0-error:0.03076	validation_1-logloss:0.13309	validation_1-error:0.03076
# [48]	validation_0-logloss:0.13183	validation_0-error:0.03038	validation_1-logloss:0.13183	validation_1-error:0.03038
# [49]	validation_0-logloss:0.13113	validation_0-error:0.03001	validation_1-logloss:0.13113	validation_1-error:0.03001
# [0]	validation_0-logloss:0.39150	validation_0-error:0.14816	validation_1-logloss:0.39150	validation_1-error:0.14816
# [1]	validation_0-logloss:0.36277	validation_0-error:0.14816	validation_1-logloss:0.36277	validation_1-error:0.14816
# [2]	validation_0-logloss:0.33992	validation_0-error:0.14816	validation_1-logloss:0.33992	validation_1-error:0.14816
# [3]	validation_0-logloss:0.32100	validation_0-error:0.14666	validation_1-logloss:0.32100	validation_1-error:0.14666
# [4]	validation_0-logloss:0.30313	validation_0-error:0.10128	validation_1-logloss:0.30313	validation_1-error:0.10128
# [5]	validation_0-logloss:0.28504	validation_0-error:0.08965	validation_1-logloss:0.28504	validation_1-error:0.08965
# [6]	validation_0-logloss:0.27001	validation_0-error:0.08890	validation_1-logloss:0.27001	validation_1-error:0.08890
# [7]	validation_0-logloss:0.25753	validation_0-error:0.08590	validation_1-logloss:0.25753	validation_1-error:0.08590
# [8]	validation_0-logloss:0.24615	validation_0-error:0.08177	validation_1-logloss:0.24615	validation_1-error:0.08177
# [9]	validation_0-logloss:0.23655	validation_0-error:0.08027	validation_1-logloss:0.23655	validation_1-error:0.08027
# [10]	validation_0-logloss:0.22831	validation_0-error:0.06864	validation_1-logloss:0.22831	validation_1-error:0.06864
# [11]	validation_0-logloss:0.22050	validation_0-error:0.05926	validation_1-logloss:0.22050	validation_1-error:0.05926
# [12]	validation_0-logloss:0.21356	validation_0-error:0.05589	validation_1-logloss:0.21356	validation_1-error:0.05589
# [13]	validation_0-logloss:0.20692	validation_0-error:0.04726	validation_1-logloss:0.20692	validation_1-error:0.04726
# [14]	validation_0-logloss:0.20171	validation_0-error:0.04614	validation_1-logloss:0.20171	validation_1-error:0.04614
# [15]	validation_0-logloss:0.19668	validation_0-error:0.04464	validation_1-logloss:0.19668	validation_1-error:0.04464
# [16]	validation_0-logloss:0.19228	validation_0-error:0.04314	validation_1-logloss:0.19228	validation_1-error:0.04314
# [17]	validation_0-logloss:0.18803	validation_0-error:0.04089	validation_1-logloss:0.18803	validation_1-error:0.04089
# [18]	validation_0-logloss:0.18381	validation_0-error:0.04126	validation_1-logloss:0.18381	validation_1-error:0.04126
# [19]	validation_0-logloss:0.18014	validation_0-error:0.03863	validation_1-logloss:0.18014	validation_1-error:0.03863
# [20]	validation_0-logloss:0.17691	validation_0-error:0.03863	validation_1-logloss:0.17691	validation_1-error:0.03863
# [21]	validation_0-logloss:0.17323	validation_0-error:0.03788	validation_1-logloss:0.17323	validation_1-error:0.03788
# [22]	validation_0-logloss:0.17032	validation_0-error:0.03751	validation_1-logloss:0.17032	validation_1-error:0.03751
# [23]	validation_0-logloss:0.16734	validation_0-error:0.03751	validation_1-logloss:0.16734	validation_1-error:0.03751
# [24]	validation_0-logloss:0.16393	validation_0-error:0.03676	validation_1-logloss:0.16393	validation_1-error:0.03676
# [25]	validation_0-logloss:0.16158	validation_0-error:0.03713	validation_1-logloss:0.16158	validation_1-error:0.03713
# [26]	validation_0-logloss:0.15927	validation_0-error:0.03713	validation_1-logloss:0.15927	validation_1-error:0.03713
# [27]	validation_0-logloss:0.15749	validation_0-error:0.03676	validation_1-logloss:0.15749	validation_1-error:0.03676
# [28]	validation_0-logloss:0.15551	validation_0-error:0.03563	validation_1-logloss:0.15551	validation_1-error:0.03563
# [29]	validation_0-logloss:0.15358	validation_0-error:0.03563	validation_1-logloss:0.15358	validation_1-error:0.03563
# [30]	validation_0-logloss:0.15184	validation_0-error:0.03563	validation_1-logloss:0.15184	validation_1-error:0.03563
# [31]	validation_0-logloss:0.14967	validation_0-error:0.03376	validation_1-logloss:0.14967	validation_1-error:0.03376
# [32]	validation_0-logloss:0.14796	validation_0-error:0.03338	validation_1-logloss:0.14796	validation_1-error:0.03338
# [33]	validation_0-logloss:0.14618	validation_0-error:0.03338	validation_1-logloss:0.14618	validation_1-error:0.03338
# [34]	validation_0-logloss:0.14433	validation_0-error:0.03301	validation_1-logloss:0.14433	validation_1-error:0.03301
# [35]	validation_0-logloss:0.14265	validation_0-error:0.03226	validation_1-logloss:0.14265	validation_1-error:0.03226
# [36]	validation_0-logloss:0.14087	validation_0-error:0.03301	validation_1-logloss:0.14087	validation_1-error:0.03301
# [37]	validation_0-logloss:0.13964	validation_0-error:0.03301	validation_1-logloss:0.13964	validation_1-error:0.03301
# [38]	validation_0-logloss:0.13823	validation_0-error:0.03263	validation_1-logloss:0.13823	validation_1-error:0.03263
# [39]	validation_0-logloss:0.13664	validation_0-error:0.03113	validation_1-logloss:0.13664	validation_1-error:0.03113
# [40]	validation_0-logloss:0.13486	validation_0-error:0.03113	validation_1-logloss:0.13486	validation_1-error:0.03113
# [41]	validation_0-logloss:0.13433	validation_0-error:0.03113	validation_1-logloss:0.13433	validation_1-error:0.03113
# [42]	validation_0-logloss:0.13328	validation_0-error:0.03113	validation_1-logloss:0.13328	validation_1-error:0.03113
# [43]	validation_0-logloss:0.13168	validation_0-error:0.03151	validation_1-logloss:0.13168	validation_1-error:0.03151
# [44]	validation_0-logloss:0.13082	validation_0-error:0.03151	validation_1-logloss:0.13082	validation_1-error:0.03151
# [45]	validation_0-logloss:0.12978	validation_0-error:0.03151	validation_1-logloss:0.12978	validation_1-error:0.03151
# [46]	validation_0-logloss:0.12887	validation_0-error:0.03076	validation_1-logloss:0.12887	validation_1-error:0.03076
# [47]	validation_0-logloss:0.12722	validation_0-error:0.02963	validation_1-logloss:0.12722	validation_1-error:0.02963
# [48]	validation_0-logloss:0.12629	validation_0-error:0.02963	validation_1-logloss:0.12629	validation_1-error:0.02963
# [49]	validation_0-logloss:0.12578	validation_0-error:0.02926	validation_1-logloss:0.12578	validation_1-error:0.02926
# [0]	validation_0-logloss:0.38994	validation_0-error:0.14816	validation_1-logloss:0.38994	validation_1-error:0.14816
# C:\Users\prash\anaconda3\Lib\site-packages\xgboost\sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\prash\anaconda3\Lib\site-packages\xgboost\sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [1]	validation_0-logloss:0.35922	validation_0-error:0.14816	validation_1-logloss:0.35922	validation_1-error:0.14816
# [2]	validation_0-logloss:0.33502	validation_0-error:0.14816	validation_1-logloss:0.33502	validation_1-error:0.14816
# [3]	validation_0-logloss:0.31444	validation_0-error:0.14816	validation_1-logloss:0.31444	validation_1-error:0.14816
# [4]	validation_0-logloss:0.29761	validation_0-error:0.10128	validation_1-logloss:0.29761	validation_1-error:0.10128
# [5]	validation_0-logloss:0.28218	validation_0-error:0.09940	validation_1-logloss:0.28218	validation_1-error:0.09940
# [6]	validation_0-logloss:0.26873	validation_0-error:0.08890	validation_1-logloss:0.26873	validation_1-error:0.08890
# [7]	validation_0-logloss:0.25724	validation_0-error:0.08440	validation_1-logloss:0.25724	validation_1-error:0.08440
# [8]	validation_0-logloss:0.24561	validation_0-error:0.07914	validation_1-logloss:0.24561	validation_1-error:0.07914
# [9]	validation_0-logloss:0.23577	validation_0-error:0.06714	validation_1-logloss:0.23577	validation_1-error:0.06714
# [10]	validation_0-logloss:0.22695	validation_0-error:0.06377	validation_1-logloss:0.22695	validation_1-error:0.06377
# [11]	validation_0-logloss:0.21925	validation_0-error:0.06339	validation_1-logloss:0.21925	validation_1-error:0.06339
# [12]	validation_0-logloss:0.21241	validation_0-error:0.06152	validation_1-logloss:0.21241	validation_1-error:0.06152
# [13]	validation_0-logloss:0.20697	validation_0-error:0.05251	validation_1-logloss:0.20697	validation_1-error:0.05251
# [14]	validation_0-logloss:0.20134	validation_0-error:0.05026	validation_1-logloss:0.20134	validation_1-error:0.05026
# [15]	validation_0-logloss:0.19654	validation_0-error:0.04914	validation_1-logloss:0.19654	validation_1-error:0.04914
# [16]	validation_0-logloss:0.19232	validation_0-error:0.04651	validation_1-logloss:0.19232	validation_1-error:0.04651
# [17]	validation_0-logloss:0.18809	validation_0-error:0.04014	validation_1-logloss:0.18809	validation_1-error:0.04014
# [18]	validation_0-logloss:0.18450	validation_0-error:0.03976	validation_1-logloss:0.18450	validation_1-error:0.03976
# [19]	validation_0-logloss:0.18060	validation_0-error:0.04089	validation_1-logloss:0.18060	validation_1-error:0.04089
# [20]	validation_0-logloss:0.17791	validation_0-error:0.04014	validation_1-logloss:0.17791	validation_1-error:0.04014
# [21]	validation_0-logloss:0.17557	validation_0-error:0.03938	validation_1-logloss:0.17557	validation_1-error:0.03938
# [22]	validation_0-logloss:0.17244	validation_0-error:0.03863	validation_1-logloss:0.17244	validation_1-error:0.03863
# [23]	validation_0-logloss:0.17058	validation_0-error:0.03826	validation_1-logloss:0.17058	validation_1-error:0.03826
# [24]	validation_0-logloss:0.16802	validation_0-error:0.03676	validation_1-logloss:0.16802	validation_1-error:0.03676
# [25]	validation_0-logloss:0.16574	validation_0-error:0.03601	validation_1-logloss:0.16574	validation_1-error:0.03601
# [26]	validation_0-logloss:0.16417	validation_0-error:0.03601	validation_1-logloss:0.16417	validation_1-error:0.03601
# [27]	validation_0-logloss:0.16213	validation_0-error:0.03526	validation_1-logloss:0.16213	validation_1-error:0.03526
# [28]	validation_0-logloss:0.16020	validation_0-error:0.03526	validation_1-logloss:0.16020	validation_1-error:0.03526
# [29]	validation_0-logloss:0.15849	validation_0-error:0.03451	validation_1-logloss:0.15849	validation_1-error:0.03451
# [30]	validation_0-logloss:0.15694	validation_0-error:0.03451	validation_1-logloss:0.15694	validation_1-error:0.03451
# [31]	validation_0-logloss:0.15546	validation_0-error:0.03413	validation_1-logloss:0.15546	validation_1-error:0.03413
# [32]	validation_0-logloss:0.15410	validation_0-error:0.03413	validation_1-logloss:0.15410	validation_1-error:0.03413
# [33]	validation_0-logloss:0.15239	validation_0-error:0.03451	validation_1-logloss:0.15239	validation_1-error:0.03451
# [34]	validation_0-logloss:0.15098	validation_0-error:0.03301	validation_1-logloss:0.15098	validation_1-error:0.03301
# [35]	validation_0-logloss:0.15027	validation_0-error:0.03188	validation_1-logloss:0.15027	validation_1-error:0.03188
# [36]	validation_0-logloss:0.14800	validation_0-error:0.03151	validation_1-logloss:0.14800	validation_1-error:0.03151
# [37]	validation_0-logloss:0.14687	validation_0-error:0.03151	validation_1-logloss:0.14687	validation_1-error:0.03151
# [38]	validation_0-logloss:0.14541	validation_0-error:0.03076	validation_1-logloss:0.14541	validation_1-error:0.03076
# [39]	validation_0-logloss:0.14458	validation_0-error:0.03076	validation_1-logloss:0.14458	validation_1-error:0.03076
# [40]	validation_0-logloss:0.14343	validation_0-error:0.03038	validation_1-logloss:0.14343	validation_1-error:0.03038
# [41]	validation_0-logloss:0.14265	validation_0-error:0.03076	validation_1-logloss:0.14265	validation_1-error:0.03076
# [42]	validation_0-logloss:0.14143	validation_0-error:0.03038	validation_1-logloss:0.14143	validation_1-error:0.03038
# [43]	validation_0-logloss:0.14052	validation_0-error:0.03038	validation_1-logloss:0.14052	validation_1-error:0.03038
# [44]	validation_0-logloss:0.13915	validation_0-error:0.03076	validation_1-logloss:0.13915	validation_1-error:0.03076
# [45]	validation_0-logloss:0.13742	validation_0-error:0.03038	validation_1-logloss:0.13742	validation_1-error:0.03038
# [46]	validation_0-logloss:0.13649	validation_0-error:0.03038	validation_1-logloss:0.13649	validation_1-error:0.03038
# [47]	validation_0-logloss:0.13555	validation_0-error:0.03001	validation_1-logloss:0.13555	validation_1-error:0.03001
# [48]	validation_0-logloss:0.13508	validation_0-error:0.03001	validation_1-logloss:0.13508	validation_1-error:0.03001
# [49]	validation_0-logloss:0.13314	validation_0-error:0.03001	validation_1-logloss:0.13314	validation_1-error:0.03001
# [0]	validation_0-logloss:0.39012	validation_0-error:0.14816	validation_1-logloss:0.39012	validation_1-error:0.14816
# [1]	validation_0-logloss:0.36167	validation_0-error:0.14816	validation_1-logloss:0.36167	validation_1-error:0.14816
# [2]	validation_0-logloss:0.33943	validation_0-error:0.14816	validation_1-logloss:0.33943	validation_1-error:0.14816
# [3]	validation_0-logloss:0.31881	validation_0-error:0.14816	validation_1-logloss:0.31881	validation_1-error:0.14816
# [4]	validation_0-logloss:0.30088	validation_0-error:0.09940	validation_1-logloss:0.30088	validation_1-error:0.09940
# [5]	validation_0-logloss:0.28559	validation_0-error:0.09640	validation_1-logloss:0.28559	validation_1-error:0.09640
# [6]	validation_0-logloss:0.27228	validation_0-error:0.09227	validation_1-logloss:0.27228	validation_1-error:0.09227
# [7]	validation_0-logloss:0.25869	validation_0-error:0.08777	validation_1-logloss:0.25869	validation_1-error:0.08777
# [8]	validation_0-logloss:0.24656	validation_0-error:0.08627	validation_1-logloss:0.24656	validation_1-error:0.08627
# [9]	validation_0-logloss:0.23652	validation_0-error:0.07539	validation_1-logloss:0.23652	validation_1-error:0.07539
# [10]	validation_0-logloss:0.22753	validation_0-error:0.07352	validation_1-logloss:0.22753	validation_1-error:0.07352
# [11]	validation_0-logloss:0.21963	validation_0-error:0.07089	validation_1-logloss:0.21963	validation_1-error:0.07089
# [12]	validation_0-logloss:0.21270	validation_0-error:0.06902	validation_1-logloss:0.21270	validation_1-error:0.06902
# [13]	validation_0-logloss:0.20581	validation_0-error:0.06152	validation_1-logloss:0.20581	validation_1-error:0.06152
# [14]	validation_0-logloss:0.20091	validation_0-error:0.05851	validation_1-logloss:0.20091	validation_1-error:0.05851
# [15]	validation_0-logloss:0.19540	validation_0-error:0.04651	validation_1-logloss:0.19540	validation_1-error:0.04651
# [16]	validation_0-logloss:0.19033	validation_0-error:0.04276	validation_1-logloss:0.19033	validation_1-error:0.04276
# [17]	validation_0-logloss:0.18674	validation_0-error:0.04464	validation_1-logloss:0.18674	validation_1-error:0.04464
# [18]	validation_0-logloss:0.18258	validation_0-error:0.04126	validation_1-logloss:0.18258	validation_1-error:0.04126
# [19]	validation_0-logloss:0.17975	validation_0-error:0.04351	validation_1-logloss:0.17975	validation_1-error:0.04351
# [20]	validation_0-logloss:0.17633	validation_0-error:0.04089	validation_1-logloss:0.17633	validation_1-error:0.04089
# [21]	validation_0-logloss:0.17331	validation_0-error:0.03976	validation_1-logloss:0.17331	validation_1-error:0.03976
# [22]	validation_0-logloss:0.17012	validation_0-error:0.04051	validation_1-logloss:0.17012	validation_1-error:0.04051
# [23]	validation_0-logloss:0.16776	validation_0-error:0.04014	validation_1-logloss:0.16776	validation_1-error:0.04014
# [24]	validation_0-logloss:0.16494	validation_0-error:0.03863	validation_1-logloss:0.16494	validation_1-error:0.03863
# [25]	validation_0-logloss:0.16266	validation_0-error:0.03826	validation_1-logloss:0.16266	validation_1-error:0.03826
# [26]	validation_0-logloss:0.16027	validation_0-error:0.03751	validation_1-logloss:0.16027	validation_1-error:0.03751
# [27]	validation_0-logloss:0.15806	validation_0-error:0.03713	validation_1-logloss:0.15806	validation_1-error:0.03713
# [28]	validation_0-logloss:0.15620	validation_0-error:0.03713	validation_1-logloss:0.15620	validation_1-error:0.03713
# [29]	validation_0-logloss:0.15476	validation_0-error:0.03713	validation_1-logloss:0.15476	validation_1-error:0.03713
# [30]	validation_0-logloss:0.15313	validation_0-error:0.03713	validation_1-logloss:0.15313	validation_1-error:0.03713
# [31]	validation_0-logloss:0.15063	validation_0-error:0.03601	validation_1-logloss:0.15063	validation_1-error:0.03601
# [32]	validation_0-logloss:0.14874	validation_0-error:0.03638	validation_1-logloss:0.14874	validation_1-error:0.03638
# [33]	validation_0-logloss:0.14638	validation_0-error:0.03526	validation_1-logloss:0.14638	validation_1-error:0.03526
# [34]	validation_0-logloss:0.14563	validation_0-error:0.03413	validation_1-logloss:0.14563	validation_1-error:0.03413
# [35]	validation_0-logloss:0.14378	validation_0-error:0.03338	validation_1-logloss:0.14378	validation_1-error:0.03338
# [36]	validation_0-logloss:0.14185	validation_0-error:0.03338	validation_1-logloss:0.14185	validation_1-error:0.03338
# [37]	validation_0-logloss:0.14022	validation_0-error:0.03376	validation_1-logloss:0.14022	validation_1-error:0.03376
# [38]	validation_0-logloss:0.13929	validation_0-error:0.03338	validation_1-logloss:0.13929	validation_1-error:0.03338
# [39]	validation_0-logloss:0.13793	validation_0-error:0.03338	validation_1-logloss:0.13793	validation_1-error:0.03338
# [40]	validation_0-logloss:0.13682	validation_0-error:0.03338	validation_1-logloss:0.13682	validation_1-error:0.03338
# [41]	validation_0-logloss:0.13507	validation_0-error:0.03263	validation_1-logloss:0.13507	validation_1-error:0.03263
# [42]	validation_0-logloss:0.13351	validation_0-error:0.03301	validation_1-logloss:0.13351	validation_1-error:0.03301
# [43]	validation_0-logloss:0.13233	validation_0-error:0.03301	validation_1-logloss:0.13233	validation_1-error:0.03301
# [44]	validation_0-logloss:0.13122	validation_0-error:0.03301	validation_1-logloss:0.13122	validation_1-error:0.03301
# [45]	validation_0-logloss:0.13059	validation_0-error:0.03263	validation_1-logloss:0.13059	validation_1-error:0.03263
# [46]	validation_0-logloss:0.12967	validation_0-error:0.03226	validation_1-logloss:0.12967	validation_1-error:0.03226
# [47]	validation_0-logloss:0.12854	validation_0-error:0.03226	validation_1-logloss:0.12854	validation_1-error:0.03226
# [48]	validation_0-logloss:0.12797	validation_0-error:0.03226	validation_1-logloss:0.12797	validation_1-error:0.03226
# [49]	validation_0-logloss:0.12718	validation_0-error:0.03151	validation_1-logloss:0.12718	validation_1-error:0.03151
# [0]	validation_0-logloss:0.39046	validation_0-error:0.14816	validation_1-logloss:0.39046	validation_1-error:0.14816
# C:\Users\prash\anaconda3\Lib\site-packages\xgboost\sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# C:\Users\prash\anaconda3\Lib\site-packages\xgboost\sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [1]	validation_0-logloss:0.36221	validation_0-error:0.14816	validation_1-logloss:0.36221	validation_1-error:0.14816
# [2]	validation_0-logloss:0.33880	validation_0-error:0.14816	validation_1-logloss:0.33880	validation_1-error:0.14816
# [3]	validation_0-logloss:0.31911	validation_0-error:0.14816	validation_1-logloss:0.31911	validation_1-error:0.14816
# [4]	validation_0-logloss:0.30179	validation_0-error:0.12603	validation_1-logloss:0.30179	validation_1-error:0.12603
# [5]	validation_0-logloss:0.28639	validation_0-error:0.09865	validation_1-logloss:0.28639	validation_1-error:0.09865
# [6]	validation_0-logloss:0.27366	validation_0-error:0.09752	validation_1-logloss:0.27366	validation_1-error:0.09752
# [7]	validation_0-logloss:0.26248	validation_0-error:0.09377	validation_1-logloss:0.26248	validation_1-error:0.09377
# [8]	validation_0-logloss:0.25203	validation_0-error:0.08965	validation_1-logloss:0.25203	validation_1-error:0.08965
# [9]	validation_0-logloss:0.24322	validation_0-error:0.07989	validation_1-logloss:0.24322	validation_1-error:0.07989
# [10]	validation_0-logloss:0.23310	validation_0-error:0.06827	validation_1-logloss:0.23310	validation_1-error:0.06827
# [11]	validation_0-logloss:0.22444	validation_0-error:0.06602	validation_1-logloss:0.22444	validation_1-error:0.06602
# [12]	validation_0-logloss:0.21753	validation_0-error:0.06189	validation_1-logloss:0.21753	validation_1-error:0.06189
# [13]	validation_0-logloss:0.21060	validation_0-error:0.05139	validation_1-logloss:0.21060	validation_1-error:0.05139
# [14]	validation_0-logloss:0.20465	validation_0-error:0.05026	validation_1-logloss:0.20465	validation_1-error:0.05026
# [15]	validation_0-logloss:0.19934	validation_0-error:0.04876	validation_1-logloss:0.19934	validation_1-error:0.04876
# [16]	validation_0-logloss:0.19513	validation_0-error:0.04614	validation_1-logloss:0.19513	validation_1-error:0.04614
# [17]	validation_0-logloss:0.19036	validation_0-error:0.04426	validation_1-logloss:0.19036	validation_1-error:0.04426
# [18]	validation_0-logloss:0.18656	validation_0-error:0.03938	validation_1-logloss:0.18656	validation_1-error:0.03938
# [19]	validation_0-logloss:0.18316	validation_0-error:0.03938	validation_1-logloss:0.18316	validation_1-error:0.03938
# [20]	validation_0-logloss:0.18001	validation_0-error:0.03788	validation_1-logloss:0.18001	validation_1-error:0.03788
# [21]	validation_0-logloss:0.17722	validation_0-error:0.03788	validation_1-logloss:0.17722	validation_1-error:0.03788
# [22]	validation_0-logloss:0.17452	validation_0-error:0.03638	validation_1-logloss:0.17452	validation_1-error:0.03638
# [23]	validation_0-logloss:0.17119	validation_0-error:0.03526	validation_1-logloss:0.17119	validation_1-error:0.03526
# [24]	validation_0-logloss:0.16927	validation_0-error:0.03376	validation_1-logloss:0.16927	validation_1-error:0.03376
# [25]	validation_0-logloss:0.16593	validation_0-error:0.03413	validation_1-logloss:0.16593	validation_1-error:0.03413
# [26]	validation_0-logloss:0.16327	validation_0-error:0.03413	validation_1-logloss:0.16327	validation_1-error:0.03413
# [27]	validation_0-logloss:0.16060	validation_0-error:0.03338	validation_1-logloss:0.16060	validation_1-error:0.03338
# [28]	validation_0-logloss:0.15852	validation_0-error:0.03338	validation_1-logloss:0.15852	validation_1-error:0.03338
# [29]	validation_0-logloss:0.15636	validation_0-error:0.03338	validation_1-logloss:0.15636	validation_1-error:0.03338
# [30]	validation_0-logloss:0.15432	validation_0-error:0.03226	validation_1-logloss:0.15432	validation_1-error:0.03226
# [31]	validation_0-logloss:0.15294	validation_0-error:0.03301	validation_1-logloss:0.15294	validation_1-error:0.03301
# [32]	validation_0-logloss:0.15146	validation_0-error:0.03263	validation_1-logloss:0.15146	validation_1-error:0.03263
# [33]	validation_0-logloss:0.15017	validation_0-error:0.03226	validation_1-logloss:0.15017	validation_1-error:0.03226
# [34]	validation_0-logloss:0.14806	validation_0-error:0.03188	validation_1-logloss:0.14806	validation_1-error:0.03188
# [35]	validation_0-logloss:0.14661	validation_0-error:0.03263	validation_1-logloss:0.14661	validation_1-error:0.03263
# [36]	validation_0-logloss:0.14573	validation_0-error:0.03263	validation_1-logloss:0.14573	validation_1-error:0.03263
# [37]	validation_0-logloss:0.14396	validation_0-error:0.03188	validation_1-logloss:0.14396	validation_1-error:0.03188
# [38]	validation_0-logloss:0.14310	validation_0-error:0.03113	validation_1-logloss:0.14310	validation_1-error:0.03113
# [39]	validation_0-logloss:0.14171	validation_0-error:0.03038	validation_1-logloss:0.14171	validation_1-error:0.03038
# [40]	validation_0-logloss:0.14010	validation_0-error:0.03113	validation_1-logloss:0.14010	validation_1-error:0.03113
# [41]	validation_0-logloss:0.13890	validation_0-error:0.03038	validation_1-logloss:0.13890	validation_1-error:0.03038
# [42]	validation_0-logloss:0.13791	validation_0-error:0.03076	validation_1-logloss:0.13791	validation_1-error:0.03076
# [43]	validation_0-logloss:0.13708	validation_0-error:0.03076	validation_1-logloss:0.13708	validation_1-error:0.03076
# [44]	validation_0-logloss:0.13614	validation_0-error:0.03001	validation_1-logloss:0.13614	validation_1-error:0.03001
# [45]	validation_0-logloss:0.13439	validation_0-error:0.03001	validation_1-logloss:0.13439	validation_1-error:0.03001
# [46]	validation_0-logloss:0.13309	validation_0-error:0.02963	validation_1-logloss:0.13309	validation_1-error:0.02963
# [47]	validation_0-logloss:0.13210	validation_0-error:0.02926	validation_1-logloss:0.13210	validation_1-error:0.02926
# [48]	validation_0-logloss:0.13142	validation_0-error:0.02926	validation_1-logloss:0.13142	validation_1-error:0.02926
# [49]	validation_0-logloss:0.13036	validation_0-error:0.02963	validation_1-logloss:0.13036	validation_1-error:0.02963
# [50]	validation_0-logloss:0.12940	validation_0-error:0.02963	validation_1-logloss:0.12940	validation_1-error:0.02963
# [51]	validation_0-logloss:0.12872	validation_0-error:0.03038	validation_1-logloss:0.12872	validation_1-error:0.03038
# [52]	validation_0-logloss:0.12755	validation_0-error:0.03076	validation_1-logloss:0.12755	validation_1-error:0.03076
# [53]	validation_0-logloss:0.12687	validation_0-error:0.03151	validation_1-logloss:0.12687	validation_1-error:0.03151
# [54]	validation_0-logloss:0.12567	validation_0-error:0.03151	validation_1-logloss:0.12567	validation_1-error:0.03151
# [55]	validation_0-logloss:0.12508	validation_0-error:0.03076	validation_1-logloss:0.12508	validation_1-error:0.03076
# [56]	validation_0-logloss:0.12446	validation_0-error:0.03038	validation_1-logloss:0.12446	validation_1-error:0.03038
# [57]	validation_0-logloss:0.12401	validation_0-error:0.03038	validation_1-logloss:0.12401	validation_1-error:0.03038
# [58]	validation_0-logloss:0.12244	validation_0-error:0.03038	validation_1-logloss:0.12244	validation_1-error:0.03038
# [59]	validation_0-logloss:0.12181	validation_0-error:0.03038	validation_1-logloss:0.12181	validation_1-error:0.03038
# [60]	validation_0-logloss:0.12093	validation_0-error:0.02963	validation_1-logloss:0.12093	validation_1-error:0.02963
# [61]	validation_0-logloss:0.12057	validation_0-error:0.02963	validation_1-logloss:0.12057	validation_1-error:0.02963
# [62]	validation_0-logloss:0.11996	validation_0-error:0.02963	validation_1-logloss:0.11996	validation_1-error:0.02963
# [63]	validation_0-logloss:0.11930	validation_0-error:0.02926	validation_1-logloss:0.11930	validation_1-error:0.02926
# [64]	validation_0-logloss:0.11886	validation_0-error:0.02851	validation_1-logloss:0.11886	validation_1-error:0.02851
# [65]	validation_0-logloss:0.11815	validation_0-error:0.02926	validation_1-logloss:0.11815	validation_1-error:0.02926
# [66]	validation_0-logloss:0.11775	validation_0-error:0.02926	validation_1-logloss:0.11775	validation_1-error:0.02926
# [67]	validation_0-logloss:0.11673	validation_0-error:0.02776	validation_1-logloss:0.11673	validation_1-error:0.02776
# [68]	validation_0-logloss:0.11614	validation_0-error:0.02776	validation_1-logloss:0.11614	validation_1-error:0.02776
# [69]	validation_0-logloss:0.11570	validation_0-error:0.02738	validation_1-logloss:0.11570	validation_1-error:0.02738
# [70]	validation_0-logloss:0.11468	validation_0-error:0.02701	validation_1-logloss:0.11468	validation_1-error:0.02701
# [71]	validation_0-logloss:0.11401	validation_0-error:0.02738	validation_1-logloss:0.11401	validation_1-error:0.02738
# [72]	validation_0-logloss:0.11308	validation_0-error:0.02776	validation_1-logloss:0.11308	validation_1-error:0.02776
# [73]	validation_0-logloss:0.11278	validation_0-error:0.02738	validation_1-logloss:0.11278	validation_1-error:0.02738
# [74]	validation_0-logloss:0.11231	validation_0-error:0.02776	validation_1-logloss:0.11231	validation_1-error:0.02776
# [0]	validation_0-logloss:0.38944	validation_0-error:0.14816	validation_1-logloss:0.38944	validation_1-error:0.14816
# [1]	validation_0-logloss:0.35907	validation_0-error:0.14816	validation_1-logloss:0.35907	validation_1-error:0.14816
# [2]	validation_0-logloss:0.33494	validation_0-error:0.14816	validation_1-logloss:0.33494	validation_1-error:0.14816
# [3]	validation_0-logloss:0.31552	validation_0-error:0.14666	validation_1-logloss:0.31552	validation_1-error:0.14666
# [4]	validation_0-logloss:0.29883	validation_0-error:0.11890	validation_1-logloss:0.29883	validation_1-error:0.11890
# [5]	validation_0-logloss:0.28419	validation_0-error:0.09940	validation_1-logloss:0.28419	validation_1-error:0.09940
# [6]	validation_0-logloss:0.27148	validation_0-error:0.09415	validation_1-logloss:0.27148	validation_1-error:0.09415
# [7]	validation_0-logloss:0.26056	validation_0-error:0.08815	validation_1-logloss:0.26056	validation_1-error:0.08815
# [8]	validation_0-logloss:0.24832	validation_0-error:0.08402	validation_1-logloss:0.24832	validation_1-error:0.08402
# [9]	validation_0-logloss:0.23788	validation_0-error:0.08252	validation_1-logloss:0.23788	validation_1-error:0.08252
# [10]	validation_0-logloss:0.22897	validation_0-error:0.06827	validation_1-logloss:0.22897	validation_1-error:0.06827
# [11]	validation_0-logloss:0.22124	validation_0-error:0.05551	validation_1-logloss:0.22124	validation_1-error:0.05551
# [12]	validation_0-logloss:0.21258	validation_0-error:0.05589	validation_1-logloss:0.21258	validation_1-error:0.05589
# [13]	validation_0-logloss:0.20531	validation_0-error:0.05326	validation_1-logloss:0.20531	validation_1-error:0.05326
# [14]	validation_0-logloss:0.19907	validation_0-error:0.04876	validation_1-logloss:0.19907	validation_1-error:0.04876
# [15]	validation_0-logloss:0.19378	validation_0-error:0.04201	validation_1-logloss:0.19378	validation_1-error:0.04201
# [16]	validation_0-logloss:0.18908	validation_0-error:0.04126	validation_1-logloss:0.18908	validation_1-error:0.04126
# [17]	validation_0-logloss:0.18543	validation_0-error:0.04276	validation_1-logloss:0.18543	validation_1-error:0.04276
# [18]	validation_0-logloss:0.18107	validation_0-error:0.04164	validation_1-logloss:0.18107	validation_1-error:0.04164
# [19]	validation_0-logloss:0.17822	validation_0-error:0.04089	validation_1-logloss:0.17822	validation_1-error:0.04089
# [20]	validation_0-logloss:0.17527	validation_0-error:0.04051	validation_1-logloss:0.17527	validation_1-error:0.04051
# [21]	validation_0-logloss:0.17202	validation_0-error:0.03901	validation_1-logloss:0.17202	validation_1-error:0.03901
# [22]	validation_0-logloss:0.17003	validation_0-error:0.03901	validation_1-logloss:0.17003	validation_1-error:0.03901
# [23]	validation_0-logloss:0.16781	validation_0-error:0.03901	validation_1-logloss:0.16781	validation_1-error:0.03901
# [24]	validation_0-logloss:0.16493	validation_0-error:0.03826	validation_1-logloss:0.16493	validation_1-error:0.03826
# [25]	validation_0-logloss:0.16243	validation_0-error:0.03826	validation_1-logloss:0.16243	validation_1-error:0.03826
# [26]	validation_0-logloss:0.16072	validation_0-error:0.03788	validation_1-logloss:0.16072	validation_1-error:0.03788
# [27]	validation_0-logloss:0.15897	validation_0-error:0.03788	validation_1-logloss:0.15897	validation_1-error:0.03788
# [28]	validation_0-logloss:0.15675	validation_0-error:0.03638	validation_1-logloss:0.15675	validation_1-error:0.03638
# [29]	validation_0-logloss:0.15551	validation_0-error:0.03526	validation_1-logloss:0.15551	validation_1-error:0.03526
# [30]	validation_0-logloss:0.15353	validation_0-error:0.03526	validation_1-logloss:0.15353	validation_1-error:0.03526
# [31]	validation_0-logloss:0.15249	validation_0-error:0.03376	validation_1-logloss:0.15249	validation_1-error:0.03376
# [32]	validation_0-logloss:0.15080	validation_0-error:0.03413	validation_1-logloss:0.15080	validation_1-error:0.03413
# [33]	validation_0-logloss:0.14832	validation_0-error:0.03301	validation_1-logloss:0.14832	validation_1-error:0.03301
# [34]	validation_0-logloss:0.14735	validation_0-error:0.03338	validation_1-logloss:0.14735	validation_1-error:0.03338
# [35]	validation_0-logloss:0.14596	validation_0-error:0.03301	validation_1-logloss:0.14596	validation_1-error:0.03301
# [36]	validation_0-logloss:0.14503	validation_0-error:0.03188	validation_1-logloss:0.14503	validation_1-error:0.03188
# [37]	validation_0-logloss:0.14390	validation_0-error:0.03113	validation_1-logloss:0.14390	validation_1-error:0.03113
# [38]	validation_0-logloss:0.14257	validation_0-error:0.03113	validation_1-logloss:0.14257	validation_1-error:0.03113
# [39]	validation_0-logloss:0.14154	validation_0-error:0.03113	validation_1-logloss:0.14154	validation_1-error:0.03113
# [40]	validation_0-logloss:0.14008	validation_0-error:0.03113	validation_1-logloss:0.14008	validation_1-error:0.03113
# [41]	validation_0-logloss:0.13889	validation_0-error:0.03113	validation_1-logloss:0.13889	validation_1-error:0.03113
# [42]	validation_0-logloss:0.13795	validation_0-error:0.03076	validation_1-logloss:0.13795	validation_1-error:0.03076
# [43]	validation_0-logloss:0.13687	validation_0-error:0.03076	validation_1-logloss:0.13687	validation_1-error:0.03076
# [44]	validation_0-logloss:0.13578	validation_0-error:0.03076	validation_1-logloss:0.13578	validation_1-error:0.03076
# [45]	validation_0-logloss:0.13498	validation_0-error:0.03038	validation_1-logloss:0.13498	validation_1-error:0.03038
# [46]	validation_0-logloss:0.13405	validation_0-error:0.03076	validation_1-logloss:0.13405	validation_1-error:0.03076
# [47]	validation_0-logloss:0.13309	validation_0-error:0.03076	validation_1-logloss:0.13309	validation_1-error:0.03076
# [48]	validation_0-logloss:0.13183	validation_0-error:0.03038	validation_1-logloss:0.13183	validation_1-error:0.03038
# [49]	validation_0-logloss:0.13113	validation_0-error:0.03001	validation_1-logloss:0.13113	validation_1-error:0.03001
# [50]	validation_0-logloss:0.13070	validation_0-error:0.03001	validation_1-logloss:0.13070	validation_1-error:0.03001
# [51]	validation_0-logloss:0.13016	validation_0-error:0.02963	validation_1-logloss:0.13016	validation_1-error:0.02963
# [52]	validation_0-logloss:0.12938	validation_0-error:0.02963	validation_1-logloss:0.12938	validation_1-error:0.02963
# [53]	validation_0-logloss:0.12769	validation_0-error:0.02851	validation_1-logloss:0.12769	validation_1-error:0.02851
# [54]	validation_0-logloss:0.12669	validation_0-error:0.02851	validation_1-logloss:0.12669	validation_1-error:0.02851
# [55]	validation_0-logloss:0.12532	validation_0-error:0.02813	validation_1-logloss:0.12532	validation_1-error:0.02813
# C:\Users\prash\anaconda3\Lib\site-packages\xgboost\sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [56]	validation_0-logloss:0.12480	validation_0-error:0.02813	validation_1-logloss:0.12480	validation_1-error:0.02813
# [57]	validation_0-logloss:0.12426	validation_0-error:0.02813	validation_1-logloss:0.12426	validation_1-error:0.02813
# [58]	validation_0-logloss:0.12265	validation_0-error:0.02813	validation_1-logloss:0.12265	validation_1-error:0.02813
# [59]	validation_0-logloss:0.12152	validation_0-error:0.02851	validation_1-logloss:0.12152	validation_1-error:0.02851
# [60]	validation_0-logloss:0.12134	validation_0-error:0.02813	validation_1-logloss:0.12134	validation_1-error:0.02813
# [61]	validation_0-logloss:0.12074	validation_0-error:0.02813	validation_1-logloss:0.12074	validation_1-error:0.02813
# [62]	validation_0-logloss:0.11987	validation_0-error:0.02813	validation_1-logloss:0.11987	validation_1-error:0.02813
# [63]	validation_0-logloss:0.11875	validation_0-error:0.02813	validation_1-logloss:0.11875	validation_1-error:0.02813
# [64]	validation_0-logloss:0.11784	validation_0-error:0.02813	validation_1-logloss:0.11784	validation_1-error:0.02813
# [65]	validation_0-logloss:0.11727	validation_0-error:0.02851	validation_1-logloss:0.11727	validation_1-error:0.02851
# [66]	validation_0-logloss:0.11638	validation_0-error:0.02851	validation_1-logloss:0.11638	validation_1-error:0.02851
# [67]	validation_0-logloss:0.11521	validation_0-error:0.02813	validation_1-logloss:0.11521	validation_1-error:0.02813
# [68]	validation_0-logloss:0.11463	validation_0-error:0.02813	validation_1-logloss:0.11463	validation_1-error:0.02813
# [69]	validation_0-logloss:0.11397	validation_0-error:0.02776	validation_1-logloss:0.11397	validation_1-error:0.02776
# ...
# [118]	validation_0-logloss:0.09982	validation_0-error:0.02588	validation_1-logloss:0.09982	validation_1-error:0.02588
# [119]	validation_0-logloss:0.09955	validation_0-error:0.02588	validation_1-logloss:0.09955	validation_1-error:0.02588
# [0]	validation_0-logloss:0.38099	validation_0-error:0.14816	validation_1-logloss:0.38099	validation_1-error:0.14816
# [1]	validation_0-logloss:0.34676	validation_0-error:0.14816	validation_1-logloss:0.34676	validation_1-error:0.14816
# [2]	validation_0-logloss:0.31756	validation_0-error:0.14816	validation_1-logloss:0.31756	validation_1-error:0.14816
# [3]	validation_0-logloss:0.29290	validation_0-error:0.14816	validation_1-logloss:0.29290	validation_1-error:0.14816
# [4]	validation_0-logloss:0.27240	validation_0-error:0.09077	validation_1-logloss:0.27240	validation_1-error:0.09077
# [5]	validation_0-logloss:0.25561	validation_0-error:0.06902	validation_1-logloss:0.25561	validation_1-error:0.06902
# [6]	validation_0-logloss:0.24031	validation_0-error:0.05776	validation_1-logloss:0.24031	validation_1-error:0.05776
# [7]	validation_0-logloss:0.22760	validation_0-error:0.04989	validation_1-logloss:0.22760	validation_1-error:0.04989
# [8]	validation_0-logloss:0.21682	validation_0-error:0.04726	validation_1-logloss:0.21682	validation_1-error:0.04726
# [9]	validation_0-logloss:0.20671	validation_0-error:0.04314	validation_1-logloss:0.20671	validation_1-error:0.04314
# [10]	validation_0-logloss:0.19798	validation_0-error:0.04239	validation_1-logloss:0.19798	validation_1-error:0.04239
# [11]	validation_0-logloss:0.19047	validation_0-error:0.03638	validation_1-logloss:0.19047	validation_1-error:0.03638
# [12]	validation_0-logloss:0.18376	validation_0-error:0.03563	validation_1-logloss:0.18376	validation_1-error:0.03563
# [13]	validation_0-logloss:0.17658	validation_0-error:0.03413	validation_1-logloss:0.17658	validation_1-error:0.03413
# [14]	validation_0-logloss:0.17096	validation_0-error:0.03413	validation_1-logloss:0.17096	validation_1-error:0.03413
# [15]	validation_0-logloss:0.16528	validation_0-error:0.03376	validation_1-logloss:0.16528	validation_1-error:0.03376
# [16]	validation_0-logloss:0.16117	validation_0-error:0.03301	validation_1-logloss:0.16117	validation_1-error:0.03301
# [17]	validation_0-logloss:0.15640	validation_0-error:0.03226	validation_1-logloss:0.15640	validation_1-error:0.03226
# [18]	validation_0-logloss:0.15221	validation_0-error:0.03151	validation_1-logloss:0.15221	validation_1-error:0.03151
# [19]	validation_0-logloss:0.14912	validation_0-error:0.03076	validation_1-logloss:0.14912	validation_1-error:0.03076
# [20]	validation_0-logloss:0.14516	validation_0-error:0.03038	validation_1-logloss:0.14516	validation_1-error:0.03038
# [21]	validation_0-logloss:0.14263	validation_0-error:0.03038	validation_1-logloss:0.14263	validation_1-error:0.03038
# [22]	validation_0-logloss:0.13979	validation_0-error:0.03038	validation_1-logloss:0.13979	validation_1-error:0.03038
# [23]	validation_0-logloss:0.13618	validation_0-error:0.02963	validation_1-logloss:0.13618	validation_1-error:0.02963
# [24]	validation_0-logloss:0.13415	validation_0-error:0.02926	validation_1-logloss:0.13415	validation_1-error:0.02926
# [25]	validation_0-logloss:0.13148	validation_0-error:0.02851	validation_1-logloss:0.13148	validation_1-error:0.02851
# [26]	validation_0-logloss:0.12958	validation_0-error:0.02813	validation_1-logloss:0.12958	validation_1-error:0.02813
# [27]	validation_0-logloss:0.12755	validation_0-error:0.02776	validation_1-logloss:0.12755	validation_1-error:0.02776
# [28]	validation_0-logloss:0.12534	validation_0-error:0.02738	validation_1-logloss:0.12534	validation_1-error:0.02738
# [29]	validation_0-logloss:0.12372	validation_0-error:0.02701	validation_1-logloss:0.12372	validation_1-error:0.02701
# [30]	validation_0-logloss:0.12111	validation_0-error:0.02701	validation_1-logloss:0.12111	validation_1-error:0.02701
# [31]	validation_0-logloss:0.11972	validation_0-error:0.02663	validation_1-logloss:0.11972	validation_1-error:0.02663
# [32]	validation_0-logloss:0.11864	validation_0-error:0.02701	validation_1-logloss:0.11864	validation_1-error:0.02701
# [33]	validation_0-logloss:0.11638	validation_0-error:0.02663	validation_1-logloss:0.11638	validation_1-error:0.02663
# [34]	validation_0-logloss:0.11492	validation_0-error:0.02663	validation_1-logloss:0.11492	validation_1-error:0.02663
# [35]	validation_0-logloss:0.11349	validation_0-error:0.02626	validation_1-logloss:0.11349	validation_1-error:0.02626
# [36]	validation_0-logloss:0.11201	validation_0-error:0.02588	validation_1-logloss:0.11201	validation_1-error:0.02588
# [37]	validation_0-logloss:0.11092	validation_0-error:0.02588	validation_1-logloss:0.11092	validation_1-error:0.02588
# [38]	validation_0-logloss:0.10842	validation_0-error:0.02513	validation_1-logloss:0.10842	validation_1-error:0.02513
# [39]	validation_0-logloss:0.10720	validation_0-error:0.02588	validation_1-logloss:0.10720	validation_1-error:0.02588
# [40]	validation_0-logloss:0.10629	validation_0-error:0.02588	validation_1-logloss:0.10629	validation_1-error:0.02588
# [41]	validation_0-logloss:0.10459	validation_0-error:0.02476	validation_1-logloss:0.10459	validation_1-error:0.02476
# [42]	validation_0-logloss:0.10316	validation_0-error:0.02476	validation_1-logloss:0.10316	validation_1-error:0.02476
# [43]	validation_0-logloss:0.10163	validation_0-error:0.02401	validation_1-logloss:0.10163	validation_1-error:0.02401
# [44]	validation_0-logloss:0.10093	validation_0-error:0.02401	validation_1-logloss:0.10093	validation_1-error:0.02401
# [45]	validation_0-logloss:0.09946	validation_0-error:0.02401	validation_1-logloss:0.09946	validation_1-error:0.02401
# [46]	validation_0-logloss:0.09785	validation_0-error:0.02401	validation_1-logloss:0.09785	validation_1-error:0.02401
# [47]	validation_0-logloss:0.09687	validation_0-error:0.02401	validation_1-logloss:0.09687	validation_1-error:0.02401
# [48]	validation_0-logloss:0.09616	validation_0-error:0.02401	validation_1-logloss:0.09616	validation_1-error:0.02401
# [49]	validation_0-logloss:0.09474	validation_0-error:0.02401	validation_1-logloss:0.09474	validation_1-error:0.02401
# [50]	validation_0-logloss:0.09337	validation_0-error:0.02326	validation_1-logloss:0.09337	validation_1-error:0.02326
# [51]	validation_0-logloss:0.09239	validation_0-error:0.02326	validation_1-logloss:0.09239	validation_1-error:0.02326
# [52]	validation_0-logloss:0.09142	validation_0-error:0.02326	validation_1-logloss:0.09142	validation_1-error:0.02326
# [53]	validation_0-logloss:0.08992	validation_0-error:0.02326	validation_1-logloss:0.08992	validation_1-error:0.02326
# [54]	validation_0-logloss:0.08876	validation_0-error:0.02251	validation_1-logloss:0.08876	validation_1-error:0.02251
# [55]	validation_0-logloss:0.08737	validation_0-error:0.02251	validation_1-logloss:0.08737	validation_1-error:0.02251
# [56]	validation_0-logloss:0.08677	validation_0-error:0.02213	validation_1-logloss:0.08677	validation_1-error:0.02213
# [57]	validation_0-logloss:0.08606	validation_0-error:0.02213	validation_1-logloss:0.08606	validation_1-error:0.02213
# [58]	validation_0-logloss:0.08539	validation_0-error:0.02213	validation_1-logloss:0.08539	validation_1-error:0.02213
# [59]	validation_0-logloss:0.08478	validation_0-error:0.02213	validation_1-logloss:0.08478	validation_1-error:0.02213
# [60]	validation_0-logloss:0.08427	validation_0-error:0.02213	validation_1-logloss:0.08427	validation_1-error:0.02213
# [61]	validation_0-logloss:0.08379	validation_0-error:0.02138	validation_1-logloss:0.08379	validation_1-error:0.02138
# [62]	validation_0-logloss:0.08313	validation_0-error:0.02138	validation_1-logloss:0.08313	validation_1-error:0.02138
# [63]	validation_0-logloss:0.08237	validation_0-error:0.02138	validation_1-logloss:0.08237	validation_1-error:0.02138
# [64]	validation_0-logloss:0.08165	validation_0-error:0.02138	validation_1-logloss:0.08165	validation_1-error:0.02138
# [65]	validation_0-logloss:0.08115	validation_0-error:0.02138	validation_1-logloss:0.08115	validation_1-error:0.02138
# [66]	validation_0-logloss:0.08064	validation_0-error:0.02138	validation_1-logloss:0.08064	validation_1-error:0.02138
# C:\Users\prash\anaconda3\Lib\site-packages\xgboost\sklearn.py:889: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# [67]	validation_0-logloss:0.08025	validation_0-error:0.02138	validation_1-logloss:0.08025	validation_1-error:0.02138
# [68]	validation_0-logloss:0.07979	validation_0-error:0.02138	validation_1-logloss:0.07979	validation_1-error:0.02138
# [69]	validation_0-logloss:0.07896	validation_0-error:0.02138	validation_1-logloss:0.07896	validation_1-error:0.02138
# [70]	validation_0-logloss:0.07838	validation_0-error:0.02138	validation_1-logloss:0.07838	validation_1-error:0.02138
# [71]	validation_0-logloss:0.07692	validation_0-error:0.02138	validation_1-logloss:0.07692	validation_1-error:0.02138
# [72]	validation_0-logloss:0.07648	validation_0-error:0.02101	validation_1-logloss:0.07648	validation_1-error:0.02101
# [73]	validation_0-logloss:0.07572	validation_0-error:0.02101	validation_1-logloss:0.07572	validation_1-error:0.02101
# [74]	validation_0-logloss:0.07518	validation_0-error:0.01950	validation_1-logloss:0.07518	validation_1-error:0.01950
# [75]	validation_0-logloss:0.07475	validation_0-error:0.01950	validation_1-logloss:0.07475	validation_1-error:0.01950
# [76]	validation_0-logloss:0.07428	validation_0-error:0.01913	validation_1-logloss:0.07428	validation_1-error:0.01913
# [77]	validation_0-logloss:0.07346	validation_0-error:0.01913	validation_1-logloss:0.07346	validation_1-error:0.01913
# [78]	validation_0-logloss:0.07308	validation_0-error:0.01913	validation_1-logloss:0.07308	validation_1-error:0.01913
# [79]	validation_0-logloss:0.07260	validation_0-error:0.01913	validation_1-logloss:0.07260	validation_1-error:0.01913
# [80]	validation_0-logloss:0.07204	validation_0-error:0.01838	validation_1-logloss:0.07204	validation_1-error:0.01838
# [81]	validation_0-logloss:0.07168	validation_0-error:0.01838	validation_1-logloss:0.07168	validation_1-error:0.01838
# [82]	validation_0-logloss:0.07061	validation_0-error:0.01763	validation_1-logloss:0.07061	validation_1-error:0.01763
# [83]	validation_0-logloss:0.07033	validation_0-error:0.01688	validation_1-logloss:0.07033	validation_1-error:0.01688
# [84]	validation_0-logloss:0.07002	validation_0-error:0.01688	validation_1-logloss:0.07002	validation_1-error:0.01688
# [85]	validation_0-logloss:0.06975	validation_0-error:0.01688	validation_1-logloss:0.06975	validation_1-error:0.01688
# [86]	validation_0-logloss:0.06938	validation_0-error:0.01650	validation_1-logloss:0.06938	validation_1-error:0.01650
# [87]	validation_0-logloss:0.06903	validation_0-error:0.01650	validation_1-logloss:0.06903	validation_1-error:0.01650
# [88]	validation_0-logloss:0.06858	validation_0-error:0.01650	validation_1-logloss:0.06858	validation_1-error:0.01650
# [89]	validation_0-logloss:0.06825	validation_0-error:0.01650	validation_1-logloss:0.06825	validation_1-error:0.01650
# [90]	validation_0-logloss:0.06738	validation_0-error:0.01613	validation_1-logloss:0.06738	validation_1-error:0.01613
# [91]	validation_0-logloss:0.06697	validation_0-error:0.01613	validation_1-logloss:0.06697	validation_1-error:0.01613
# [92]	validation_0-logloss:0.06670	validation_0-error:0.01613	validation_1-logloss:0.06670	validation_1-error:0.01613
# [93]	validation_0-logloss:0.06573	validation_0-error:0.01613	validation_1-logloss:0.06573	validation_1-error:0.01613
# [94]	validation_0-logloss:0.06541	validation_0-error:0.01613	validation_1-logloss:0.06541	validation_1-error:0.01613
# [95]	validation_0-logloss:0.06520	validation_0-error:0.01613	validation_1-logloss:0.06520	validation_1-error:0.01613
# [96]	validation_0-logloss:0.06408	validation_0-error:0.01538	validation_1-logloss:0.06408	validation_1-error:0.01538
# [97]	validation_0-logloss:0.06392	validation_0-error:0.01538	validation_1-logloss:0.06392	validation_1-error:0.01538
# [98]	validation_0-logloss:0.06366	validation_0-error:0.01538	validation_1-logloss:0.06366	validation_1-error:0.01538
# [99]	validation_0-logloss:0.06335	validation_0-error:0.01538	validation_1-logloss:0.06335	validation_1-error:0.01538
# [100]	validation_0-logloss:0.06255	validation_0-error:0.01538	validation_1-logloss:0.06255	validation_1-error:0.01538
# [101]	validation_0-logloss:0.06231	validation_0-error:0.01538	validation_1-logloss:0.06231	validation_1-error:0.01538
# [102]	validation_0-logloss:0.06215	validation_0-error:0.01538	validation_1-logloss:0.06215	validation_1-error:0.01538
# [103]	validation_0-logloss:0.06195	validation_0-error:0.01538	validation_1-logloss:0.06195	validation_1-error:0.01538
# [104]	validation_0-logloss:0.06096	validation_0-error:0.01463	validation_1-logloss:0.06096	validation_1-error:0.01463
# [105]	validation_0-logloss:0.05974	validation_0-error:0.01425	validation_1-logloss:0.05974	validation_1-error:0.01425
# [106]	validation_0-logloss:0.05958	validation_0-error:0.01425	validation_1-logloss:0.05958	validation_1-error:0.01425
# [107]	validation_0-logloss:0.05852	validation_0-error:0.01425	validation_1-logloss:0.05852	validation_1-error:0.01425
# [108]	validation_0-logloss:0.05833	validation_0-error:0.01425	validation_1-logloss:0.05833	validation_1-error:0.01425
# [109]	validation_0-logloss:0.05716	validation_0-error:0.01425	validation_1-logloss:0.05716	validation_1-error:0.01425
# [110]	validation_0-logloss:0.05688	validation_0-error:0.01425	validation_1-logloss:0.05688	validation_1-error:0.01425
# [111]	validation_0-logloss:0.05616	validation_0-error:0.01425	validation_1-logloss:0.05616	validation_1-error:0.01425
# [112]	validation_0-logloss:0.05522	validation_0-error:0.01425	validation_1-logloss:0.05522	validation_1-error:0.01425
# [113]	validation_0-logloss:0.05419	validation_0-error:0.01388	validation_1-logloss:0.05419	validation_1-error:0.01388
# [114]	validation_0-logloss:0.05329	validation_0-error:0.01425	validation_1-logloss:0.05329	validation_1-error:0.01425
# [115]	validation_0-logloss:0.05253	validation_0-error:0.01388	validation_1-logloss:0.05253	validation_1-error:0.01388
# [116]	validation_0-logloss:0.05229	validation_0-error:0.01388	validation_1-logloss:0.05229	validation_1-error:0.01388
# [117]	validation_0-logloss:0.05145	validation_0-error:0.01388	validation_1-logloss:0.05145	validation_1-error:0.01388
# [118]	validation_0-logloss:0.05085	validation_0-error:0.01388	validation_1-logloss:0.05085	validation_1-error:0.01388
# [119]	validation_0-logloss:0.05032	validation_0-error:0.01350	validation_1-logloss:0.05032	validation_1-error:0.01350
# GridSearchCV(cv=KFold(n_splits=5, random_state=None, shuffle=False),
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,...
#                                      learning_rate=None, max_bin=None,
#                                      max_cat_threshold=None,
#                                      max_cat_to_onehot=None,
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              param_grid={'eta': [0.1, 0.05], 'max_depth': [4, 5],
#                          'n_estimators': [50, 75, 100, 120]},
#              verbose=1)

# %%
grid_xgb.best_estimator_
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eta=0.1, eval_metric=None,
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=120,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
model4=xgb.XGBClassifier(**par_xgb)

model4.fit(X_train,y_train,
          eval_set=[(X_train,y_train),(X_train,y_train)],
          eval_metric=['logloss','error'],
          verbose=True)

evals_results=model4.evals_result()
# Out:
# [0]	validation_0-logloss:0.42262	validation_0-error:0.14816	validation_1-logloss:0.42262	validation_1-error:0.14816
# [1]	validation_0-logloss:0.41792	validation_0-error:0.14816	validation_1-logloss:0.41792	validation_1-error:0.14816
# [2]	validation_0-logloss:0.41336	validation_0-error:0.14816	validation_1-logloss:0.41336	validation_1-error:0.14816
# [3]	validation_0-logloss:0.40892	validation_0-error:0.14816	validation_1-logloss:0.40892	validation_1-error:0.14816
# [4]	validation_0-logloss:0.40460	validation_0-error:0.14816	validation_1-logloss:0.40460	validation_1-error:0.14816
# [5]	validation_0-logloss:0.40040	validation_0-error:0.14816	validation_1-logloss:0.40040	validation_1-error:0.14816
# [6]	validation_0-logloss:0.39632	validation_0-error:0.14816	validation_1-logloss:0.39632	validation_1-error:0.14816
# [7]	validation_0-logloss:0.39231	validation_0-error:0.14816	validation_1-logloss:0.39231	validation_1-error:0.14816
# [8]	validation_0-logloss:0.38844	validation_0-error:0.14816	validation_1-logloss:0.38844	validation_1-error:0.14816
# [9]	validation_0-logloss:0.38464	validation_0-error:0.14816	validation_1-logloss:0.38464	validation_1-error:0.14816
# [10]	validation_0-logloss:0.38095	validation_0-error:0.14816	validation_1-logloss:0.38095	validation_1-error:0.14816
# [11]	validation_0-logloss:0.37735	validation_0-error:0.14816	validation_1-logloss:0.37735	validation_1-error:0.14816
# [12]	validation_0-logloss:0.37385	validation_0-error:0.14816	validation_1-logloss:0.37385	validation_1-error:0.14816
# [13]	validation_0-logloss:0.37040	validation_0-error:0.14816	validation_1-logloss:0.37040	validation_1-error:0.14816
# [14]	validation_0-logloss:0.36706	validation_0-error:0.14816	validation_1-logloss:0.36706	validation_1-error:0.14816
# [15]	validation_0-logloss:0.36378	validation_0-error:0.14816	validation_1-logloss:0.36378	validation_1-error:0.14816
# [16]	validation_0-logloss:0.36035	validation_0-error:0.14816	validation_1-logloss:0.36035	validation_1-error:0.14816
# [17]	validation_0-logloss:0.35700	validation_0-error:0.14816	validation_1-logloss:0.35700	validation_1-error:0.14816
# [18]	validation_0-logloss:0.35373	validation_0-error:0.14816	validation_1-logloss:0.35373	validation_1-error:0.14816
# [19]	validation_0-logloss:0.35052	validation_0-error:0.14816	validation_1-logloss:0.35052	validation_1-error:0.14816
# [20]	validation_0-logloss:0.34739	validation_0-error:0.14816	validation_1-logloss:0.34739	validation_1-error:0.14816
# [21]	validation_0-logloss:0.34433	validation_0-error:0.14816	validation_1-logloss:0.34433	validation_1-error:0.14816
# [22]	validation_0-logloss:0.34133	validation_0-error:0.14816	validation_1-logloss:0.34133	validation_1-error:0.14816
# [23]	validation_0-logloss:0.33840	validation_0-error:0.14816	validation_1-logloss:0.33840	validation_1-error:0.14816
# [24]	validation_0-logloss:0.33547	validation_0-error:0.14816	validation_1-logloss:0.33547	validation_1-error:0.14816
# [25]	validation_0-logloss:0.33266	validation_0-error:0.14816	validation_1-logloss:0.33266	validation_1-error:0.14816
# [26]	validation_0-logloss:0.32979	validation_0-error:0.14816	validation_1-logloss:0.32979	validation_1-error:0.14816
# [27]	validation_0-logloss:0.32698	validation_0-error:0.14816	validation_1-logloss:0.32698	validation_1-error:0.14816
# [28]	validation_0-logloss:0.32423	validation_0-error:0.14816	validation_1-logloss:0.32423	validation_1-error:0.14816
# [29]	validation_0-logloss:0.32153	validation_0-error:0.14816	validation_1-logloss:0.32153	validation_1-error:0.14816
# [30]	validation_0-logloss:0.31900	validation_0-error:0.14816	validation_1-logloss:0.31900	validation_1-error:0.14816
# [31]	validation_0-logloss:0.31640	validation_0-error:0.14816	validation_1-logloss:0.31640	validation_1-error:0.14816
# [32]	validation_0-logloss:0.31385	validation_0-error:0.14816	validation_1-logloss:0.31385	validation_1-error:0.14816
# [33]	validation_0-logloss:0.31139	validation_0-error:0.14816	validation_1-logloss:0.31139	validation_1-error:0.14816
# [34]	validation_0-logloss:0.30892	validation_0-error:0.14816	validation_1-logloss:0.30892	validation_1-error:0.14816
# [35]	validation_0-logloss:0.30650	validation_0-error:0.14816	validation_1-logloss:0.30650	validation_1-error:0.14816
# [36]	validation_0-logloss:0.30422	validation_0-error:0.14816	validation_1-logloss:0.30422	validation_1-error:0.14816
# [37]	validation_0-logloss:0.30188	validation_0-error:0.14816	validation_1-logloss:0.30188	validation_1-error:0.14816
# [38]	validation_0-logloss:0.29958	validation_0-error:0.14816	validation_1-logloss:0.29958	validation_1-error:0.14816
# [39]	validation_0-logloss:0.29736	validation_0-error:0.14816	validation_1-logloss:0.29736	validation_1-error:0.14816
# [40]	validation_0-logloss:0.29515	validation_0-error:0.14816	validation_1-logloss:0.29515	validation_1-error:0.14816
# [41]	validation_0-logloss:0.29306	validation_0-error:0.14816	validation_1-logloss:0.29306	validation_1-error:0.14816
# [42]	validation_0-logloss:0.29091	validation_0-error:0.14816	validation_1-logloss:0.29091	validation_1-error:0.14816
# [43]	validation_0-logloss:0.28880	validation_0-error:0.14816	validation_1-logloss:0.28880	validation_1-error:0.14816
# [44]	validation_0-logloss:0.28673	validation_0-error:0.14816	validation_1-logloss:0.28673	validation_1-error:0.14816
# [45]	validation_0-logloss:0.28476	validation_0-error:0.14816	validation_1-logloss:0.28476	validation_1-error:0.14816
# [46]	validation_0-logloss:0.28274	validation_0-error:0.14816	validation_1-logloss:0.28274	validation_1-error:0.14816
# [47]	validation_0-logloss:0.28077	validation_0-error:0.14816	validation_1-logloss:0.28077	validation_1-error:0.14816
# [48]	validation_0-logloss:0.27883	validation_0-error:0.14816	validation_1-logloss:0.27883	validation_1-error:0.14816
# [49]	validation_0-logloss:0.27697	validation_0-error:0.12641	validation_1-logloss:0.27697	validation_1-error:0.12641
# [50]	validation_0-logloss:0.27510	validation_0-error:0.12641	validation_1-logloss:0.27510	validation_1-error:0.12641
# [51]	validation_0-logloss:0.27325	validation_0-error:0.11028	validation_1-logloss:0.27325	validation_1-error:0.11028
# [52]	validation_0-logloss:0.27144	validation_0-error:0.11028	validation_1-logloss:0.27144	validation_1-error:0.11028
# [53]	validation_0-logloss:0.26970	validation_0-error:0.09227	validation_1-logloss:0.26970	validation_1-error:0.09227
# [54]	validation_0-logloss:0.26793	validation_0-error:0.08252	validation_1-logloss:0.26793	validation_1-error:0.08252
# [55]	validation_0-logloss:0.26617	validation_0-error:0.08252	validation_1-logloss:0.26617	validation_1-error:0.08252
# [56]	validation_0-logloss:0.26446	validation_0-error:0.08065	validation_1-logloss:0.26446	validation_1-error:0.08065
# [57]	validation_0-logloss:0.26283	validation_0-error:0.07764	validation_1-logloss:0.26283	validation_1-error:0.07764
# [58]	validation_0-logloss:0.26117	validation_0-error:0.07614	validation_1-logloss:0.26117	validation_1-error:0.07614
# [59]	validation_0-logloss:0.25955	validation_0-error:0.07352	validation_1-logloss:0.25955	validation_1-error:0.07352
# [60]	validation_0-logloss:0.25798	validation_0-error:0.07352	validation_1-logloss:0.25798	validation_1-error:0.07352
# [61]	validation_0-logloss:0.25637	validation_0-error:0.07352	validation_1-logloss:0.25637	validation_1-error:0.07352
# [62]	validation_0-logloss:0.25479	validation_0-error:0.07277	validation_1-logloss:0.25479	validation_1-error:0.07277
# [63]	validation_0-logloss:0.25328	validation_0-error:0.07164	validation_1-logloss:0.25328	validation_1-error:0.07164
# [64]	validation_0-logloss:0.25182	validation_0-error:0.07164	validation_1-logloss:0.25182	validation_1-error:0.07164
# [65]	validation_0-logloss:0.25032	validation_0-error:0.07052	validation_1-logloss:0.25032	validation_1-error:0.07052
# [66]	validation_0-logloss:0.24886	validation_0-error:0.06864	validation_1-logloss:0.24886	validation_1-error:0.06864
# [67]	validation_0-logloss:0.24744	validation_0-error:0.06864	validation_1-logloss:0.24744	validation_1-error:0.06864
# [68]	validation_0-logloss:0.24599	validation_0-error:0.06789	validation_1-logloss:0.24599	validation_1-error:0.06789
# [69]	validation_0-logloss:0.24463	validation_0-error:0.06789	validation_1-logloss:0.24463	validation_1-error:0.06789
# [70]	validation_0-logloss:0.24327	validation_0-error:0.06789	validation_1-logloss:0.24327	validation_1-error:0.06789
# [71]	validation_0-logloss:0.24191	validation_0-error:0.06602	validation_1-logloss:0.24191	validation_1-error:0.06602
# [72]	validation_0-logloss:0.24058	validation_0-error:0.06602	validation_1-logloss:0.24058	validation_1-error:0.06602
# [73]	validation_0-logloss:0.23924	validation_0-error:0.06339	validation_1-logloss:0.23924	validation_1-error:0.06339
# [74]	validation_0-logloss:0.23795	validation_0-error:0.06264	validation_1-logloss:0.23795	validation_1-error:0.06264
# [75]	validation_0-logloss:0.23666	validation_0-error:0.06227	validation_1-logloss:0.23666	validation_1-error:0.06227
# [76]	validation_0-logloss:0.23542	validation_0-error:0.06227	validation_1-logloss:0.23542	validation_1-error:0.06227
# [77]	validation_0-logloss:0.23411	validation_0-error:0.06189	validation_1-logloss:0.23411	validation_1-error:0.06189
# [78]	validation_0-logloss:0.23282	validation_0-error:0.06039	validation_1-logloss:0.23282	validation_1-error:0.06039
# [79]	validation_0-logloss:0.23160	validation_0-error:0.05889	validation_1-logloss:0.23160	validation_1-error:0.05889
# [80]	validation_0-logloss:0.23040	validation_0-error:0.05889	validation_1-logloss:0.23040	validation_1-error:0.05889
# [81]	validation_0-logloss:0.22918	validation_0-error:0.05889	validation_1-logloss:0.22918	validation_1-error:0.05889
# [82]	validation_0-logloss:0.22800	validation_0-error:0.05776	validation_1-logloss:0.22800	validation_1-error:0.05776
# [83]	validation_0-logloss:0.22687	validation_0-error:0.05664	validation_1-logloss:0.22687	validation_1-error:0.05664
# [84]	validation_0-logloss:0.22572	validation_0-error:0.05514	validation_1-logloss:0.22572	validation_1-error:0.05514
# [85]	validation_0-logloss:0.22463	validation_0-error:0.05476	validation_1-logloss:0.22463	validation_1-error:0.05476
# [86]	validation_0-logloss:0.22350	validation_0-error:0.04951	validation_1-logloss:0.22350	validation_1-error:0.04951
# [87]	validation_0-logloss:0.22236	validation_0-error:0.04951	validation_1-logloss:0.22236	validation_1-error:0.04951
# [88]	validation_0-logloss:0.22125	validation_0-error:0.04951	validation_1-logloss:0.22125	validation_1-error:0.04951
# [89]	validation_0-logloss:0.22018	validation_0-error:0.04914	validation_1-logloss:0.22018	validation_1-error:0.04914
# [90]	validation_0-logloss:0.21910	validation_0-error:0.04839	validation_1-logloss:0.21910	validation_1-error:0.04839
# [91]	validation_0-logloss:0.21806	validation_0-error:0.04914	validation_1-logloss:0.21806	validation_1-error:0.04914
# [92]	validation_0-logloss:0.21702	validation_0-error:0.04726	validation_1-logloss:0.21702	validation_1-error:0.04726
# [93]	validation_0-logloss:0.21602	validation_0-error:0.04689	validation_1-logloss:0.21602	validation_1-error:0.04689
# [94]	validation_0-logloss:0.21502	validation_0-error:0.04689	validation_1-logloss:0.21502	validation_1-error:0.04689
# [95]	validation_0-logloss:0.21398	validation_0-error:0.04614	validation_1-logloss:0.21398	validation_1-error:0.04614
# [96]	validation_0-logloss:0.21299	validation_0-error:0.04614	validation_1-logloss:0.21299	validation_1-error:0.04614
# [97]	validation_0-logloss:0.21203	validation_0-error:0.04614	validation_1-logloss:0.21203	validation_1-error:0.04614
# [98]	validation_0-logloss:0.21107	validation_0-error:0.04539	validation_1-logloss:0.21107	validation_1-error:0.04539
# [99]	validation_0-logloss:0.21012	validation_0-error:0.04501	validation_1-logloss:0.21012	validation_1-error:0.04501
# [100]	validation_0-logloss:0.20918	validation_0-error:0.04501	validation_1-logloss:0.20918	validation_1-error:0.04501
# [101]	validation_0-logloss:0.20825	validation_0-error:0.04501	validation_1-logloss:0.20825	validation_1-error:0.04501
# [102]	validation_0-logloss:0.20735	validation_0-error:0.04426	validation_1-logloss:0.20735	validation_1-error:0.04426
# [103]	validation_0-logloss:0.20642	validation_0-error:0.04164	validation_1-logloss:0.20642	validation_1-error:0.04164
# [104]	validation_0-logloss:0.20552	validation_0-error:0.04426	validation_1-logloss:0.20552	validation_1-error:0.04426
# [105]	validation_0-logloss:0.20464	validation_0-error:0.04164	validation_1-logloss:0.20464	validation_1-error:0.04164
# [106]	validation_0-logloss:0.20376	validation_0-error:0.04164	validation_1-logloss:0.20376	validation_1-error:0.04164
# [107]	validation_0-logloss:0.20289	validation_0-error:0.04164	validation_1-logloss:0.20289	validation_1-error:0.04164
# [108]	validation_0-logloss:0.20206	validation_0-error:0.04164	validation_1-logloss:0.20206	validation_1-error:0.04164
# [109]	validation_0-logloss:0.20123	validation_0-error:0.04164	validation_1-logloss:0.20123	validation_1-error:0.04164
# [110]	validation_0-logloss:0.20040	validation_0-error:0.04164	validation_1-logloss:0.20040	validation_1-error:0.04164
# [111]	validation_0-logloss:0.19957	validation_0-error:0.04164	validation_1-logloss:0.19957	validation_1-error:0.04164
# [112]	validation_0-logloss:0.19878	validation_0-error:0.04089	validation_1-logloss:0.19878	validation_1-error:0.04089
# [113]	validation_0-logloss:0.19796	validation_0-error:0.03826	validation_1-logloss:0.19796	validation_1-error:0.03826
# [114]	validation_0-logloss:0.19717	validation_0-error:0.03751	validation_1-logloss:0.19717	validation_1-error:0.03751
# [115]	validation_0-logloss:0.19638	validation_0-error:0.03751	validation_1-logloss:0.19638	validation_1-error:0.03751
# [116]	validation_0-logloss:0.19548	validation_0-error:0.03751	validation_1-logloss:0.19548	validation_1-error:0.03751
# [117]	validation_0-logloss:0.19459	validation_0-error:0.03751	validation_1-logloss:0.19459	validation_1-error:0.03751
# [118]	validation_0-logloss:0.19383	validation_0-error:0.03751	validation_1-logloss:0.19383	validation_1-error:0.03751
# [119]	validation_0-logloss:0.19296	validation_0-error:0.03751	validation_1-logloss:0.19296	validation_1-error:0.03751
# [120]	validation_0-logloss:0.19222	validation_0-error:0.03751	validation_1-logloss:0.19222	validation_1-error:0.03751
# [121]	validation_0-logloss:0.19138	validation_0-error:0.03751	validation_1-logloss:0.19138	validation_1-error:0.03751
# [122]	validation_0-logloss:0.19070	validation_0-error:0.03751	validation_1-logloss:0.19070	validation_1-error:0.03751
# [123]	validation_0-logloss:0.18986	validation_0-error:0.03713	validation_1-logloss:0.18986	validation_1-error:0.03713
# [124]	validation_0-logloss:0.18919	validation_0-error:0.03713	validation_1-logloss:0.18919	validation_1-error:0.03713
# [125]	validation_0-logloss:0.18837	validation_0-error:0.03713	validation_1-logloss:0.18837	validation_1-error:0.03713
# [126]	validation_0-logloss:0.18758	validation_0-error:0.03713	validation_1-logloss:0.18758	validation_1-error:0.03713
# [127]	validation_0-logloss:0.18691	validation_0-error:0.03713	validation_1-logloss:0.18691	validation_1-error:0.03713
# [128]	validation_0-logloss:0.18612	validation_0-error:0.03676	validation_1-logloss:0.18612	validation_1-error:0.03676
# [129]	validation_0-logloss:0.18534	validation_0-error:0.03676	validation_1-logloss:0.18534	validation_1-error:0.03676
# [130]	validation_0-logloss:0.18473	validation_0-error:0.03638	validation_1-logloss:0.18473	validation_1-error:0.03638
# [131]	validation_0-logloss:0.18397	validation_0-error:0.03638	validation_1-logloss:0.18397	validation_1-error:0.03638
# [132]	validation_0-logloss:0.18322	validation_0-error:0.03638	validation_1-logloss:0.18322	validation_1-error:0.03638
# [133]	validation_0-logloss:0.18262	validation_0-error:0.03638	validation_1-logloss:0.18262	validation_1-error:0.03638
# [134]	validation_0-logloss:0.18189	validation_0-error:0.03638	validation_1-logloss:0.18189	validation_1-error:0.03638
# [135]	validation_0-logloss:0.18131	validation_0-error:0.03638	validation_1-logloss:0.18131	validation_1-error:0.03638
# [136]	validation_0-logloss:0.18059	validation_0-error:0.03638	validation_1-logloss:0.18059	validation_1-error:0.03638
# [137]	validation_0-logloss:0.17989	validation_0-error:0.03638	validation_1-logloss:0.17989	validation_1-error:0.03638
# [138]	validation_0-logloss:0.17933	validation_0-error:0.03601	validation_1-logloss:0.17933	validation_1-error:0.03601
# [139]	validation_0-logloss:0.17863	validation_0-error:0.03601	validation_1-logloss:0.17863	validation_1-error:0.03601
# [140]	validation_0-logloss:0.17808	validation_0-error:0.03601	validation_1-logloss:0.17808	validation_1-error:0.03601
# [141]	validation_0-logloss:0.17740	validation_0-error:0.03488	validation_1-logloss:0.17740	validation_1-error:0.03488
# [142]	validation_0-logloss:0.17674	validation_0-error:0.03488	validation_1-logloss:0.17674	validation_1-error:0.03488
# [143]	validation_0-logloss:0.17622	validation_0-error:0.03488	validation_1-logloss:0.17622	validation_1-error:0.03488
# [144]	validation_0-logloss:0.17556	validation_0-error:0.03488	validation_1-logloss:0.17556	validation_1-error:0.03488
# [145]	validation_0-logloss:0.17504	validation_0-error:0.03451	validation_1-logloss:0.17504	validation_1-error:0.03451
# [146]	validation_0-logloss:0.17439	validation_0-error:0.03413	validation_1-logloss:0.17439	validation_1-error:0.03413
# [147]	validation_0-logloss:0.17376	validation_0-error:0.03413	validation_1-logloss:0.17376	validation_1-error:0.03413
# [148]	validation_0-logloss:0.17325	validation_0-error:0.03413	validation_1-logloss:0.17325	validation_1-error:0.03413
# [149]	validation_0-logloss:0.17263	validation_0-error:0.03413	validation_1-logloss:0.17263	validation_1-error:0.03413

# %%
pred_grid_xgb=grid_xgb.predict(X_test)
print(classification_report(y_test,pred_grid_xgb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.99      0.98       561
#            1       0.96      0.80      0.87       106
#
#     accuracy                           0.96       667
#    macro avg       0.96      0.90      0.92       667
# weighted avg       0.96      0.96      0.96       667
